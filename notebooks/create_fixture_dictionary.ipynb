# %% [markdown]
# ## Create fixture dict

# %%
import itertools

# Define attributes
sizes = ["1", "2", "3N", "3", "4N", "4", "5N", "5", "6N", "6", "7", "8", "9", "10"]
orientations = ["LEFT", "RIGHT"]
types = ["CR", "PS"]
cementing_methods = ["CLS", "CTD"]
operation = ["OP2"]

# Define size categories
size_categories = {
    "small": {"1", "2", "3N"},
    "medium": {"3", "4N", "4", "5N", "5", "6N"},
    "large": {"6", "7", "8", "9", "10"}
}

# Helper function to determine the size category
def get_size_category(size):
    for category, sizes in size_categories.items():
        if size in sizes:
            return category
    return None

# Generate all possible part IDs
part_ids = [
    f"{orientation}-{type}-{size}-{cementing}-{op}"
    for orientation, type, size, cementing, op in itertools.product(orientations, types, sizes, cementing_methods, operation)
]

# Create compatibility dictionary
compatibility_dict = {}

for part_id in part_ids:
    orientation, type, size, cementing, op = part_id.split('-')
    size_category = get_size_category(size)
    
    compatible_parts = []
    
    for other_part_id in part_ids:
        if other_part_id == part_id:
            continue
        
        other_orientation, other_type, other_size, other_cementing, other_op = other_part_id.split('-')
        other_size_category = get_size_category(other_size)
        
        if other_op != "OP2":
            continue
        
        if type == other_type and size_category == other_size_category:
            if type == "CR" or (type == "PS" and cementing == other_cementing):
                compatible_parts.append(other_part_id)
    
    compatibility_dict[part_id] = compatible_parts

# Print the compatibility dictionary (for demonstration purposes)
for part_id, compatible_parts in compatibility_dict.items():
    print(f"{part_id}: {compatible_parts}")
# Out:
# LEFT-CR-1-CLS-OP2: ['LEFT-CR-1-CTD-OP2', 'LEFT-CR-2-CLS-OP2', 'LEFT-CR-2-CTD-OP2', 'LEFT-CR-3N-CLS-OP2', 'LEFT-CR-3N-CTD-OP2', 'RIGHT-CR-1-CLS-OP2', 'RIGHT-CR-1-CTD-OP2', 'RIGHT-CR-2-CLS-OP2', 'RIGHT-CR-2-CTD-OP2', 'RIGHT-CR-3N-CLS-OP2', 'RIGHT-CR-3N-CTD-OP2']
# LEFT-CR-1-CTD-OP2: ['LEFT-CR-1-CLS-OP2', 'LEFT-CR-2-CLS-OP2', 'LEFT-CR-2-CTD-OP2', 'LEFT-CR-3N-CLS-OP2', 'LEFT-CR-3N-CTD-OP2', 'RIGHT-CR-1-CLS-OP2', 'RIGHT-CR-1-CTD-OP2', 'RIGHT-CR-2-CLS-OP2', 'RIGHT-CR-2-CTD-OP2', 'RIGHT-CR-3N-CLS-OP2', 'RIGHT-CR-3N-CTD-OP2']
# LEFT-CR-2-CLS-OP2: ['LEFT-CR-1-CLS-OP2', 'LEFT-CR-1-CTD-OP2', 'LEFT-CR-2-CTD-OP2', 'LEFT-CR-3N-CLS-OP2', 'LEFT-CR-3N-CTD-OP2', 'RIGHT-CR-1-CLS-OP2', 'RIGHT-CR-1-CTD-OP2', 'RIGHT-CR-2-CLS-OP2', 'RIGHT-CR-2-CTD-OP2', 'RIGHT-CR-3N-CLS-OP2', 'RIGHT-CR-3N-CTD-OP2']
# LEFT-CR-2-CTD-OP2: ['LEFT-CR-1-CLS-OP2', 'LEFT-CR-1-CTD-OP2', 'LEFT-CR-2-CLS-OP2', 'LEFT-CR-3N-CLS-OP2', 'LEFT-CR-3N-CTD-OP2', 'RIGHT-CR-1-CLS-OP2', 'RIGHT-CR-1-CTD-OP2', 'RIGHT-CR-2-CLS-OP2', 'RIGHT-CR-2-CTD-OP2', 'RIGHT-CR-3N-CLS-OP2', 'RIGHT-CR-3N-CTD-OP2']
# LEFT-CR-3N-CLS-OP2: ['LEFT-CR-1-CLS-OP2', 'LEFT-CR-1-CTD-OP2', 'LEFT-CR-2-CLS-OP2', 'LEFT-CR-2-CTD-OP2', 'LEFT-CR-3N-CTD-OP2', 'RIGHT-CR-1-CLS-OP2', 'RIGHT-CR-1-CTD-OP2', 'RIGHT-CR-2-CLS-OP2', 'RIGHT-CR-2-CTD-OP2', 'RIGHT-CR-3N-CLS-OP2', 'RIGHT-CR-3N-CTD-OP2']
# LEFT-CR-3N-CTD-OP2: ['LEFT-CR-1-CLS-OP2', 'LEFT-CR-1-CTD-OP2', 'LEFT-CR-2-CLS-OP2', 'LEFT-CR-2-CTD-OP2', 'LEFT-CR-3N-CLS-OP2', 'RIGHT-CR-1-CLS-OP2', 'RIGHT-CR-1-CTD-OP2', 'RIGHT-CR-2-CLS-OP2', 'RIGHT-CR-2-CTD-OP2', 'RIGHT-CR-3N-CLS-OP2', 'RIGHT-CR-3N-CTD-OP2']
# LEFT-CR-3-CLS-OP2: ['LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-3-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-4N-CLS-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-4N-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-4-CLS-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-4-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-5N-CLS-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-5N-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-5-CLS-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-5-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-6N-CLS-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-6N-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# LEFT-CR-6-CLS-OP2: ['LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# LEFT-CR-6-CTD-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# LEFT-CR-7-CLS-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# LEFT-CR-7-CTD-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# LEFT-CR-8-CLS-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# LEFT-CR-8-CTD-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# LEFT-CR-9-CLS-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# LEFT-CR-9-CTD-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# LEFT-CR-10-CLS-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# LEFT-CR-10-CTD-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# LEFT-PS-1-CLS-OP2: ['LEFT-PS-2-CLS-OP2', 'LEFT-PS-3N-CLS-OP2', 'RIGHT-PS-1-CLS-OP2', 'RIGHT-PS-2-CLS-OP2', 'RIGHT-PS-3N-CLS-OP2']
# LEFT-PS-1-CTD-OP2: ['LEFT-PS-2-CTD-OP2', 'LEFT-PS-3N-CTD-OP2', 'RIGHT-PS-1-CTD-OP2', 'RIGHT-PS-2-CTD-OP2', 'RIGHT-PS-3N-CTD-OP2']
# LEFT-PS-2-CLS-OP2: ['LEFT-PS-1-CLS-OP2', 'LEFT-PS-3N-CLS-OP2', 'RIGHT-PS-1-CLS-OP2', 'RIGHT-PS-2-CLS-OP2', 'RIGHT-PS-3N-CLS-OP2']
# LEFT-PS-2-CTD-OP2: ['LEFT-PS-1-CTD-OP2', 'LEFT-PS-3N-CTD-OP2', 'RIGHT-PS-1-CTD-OP2', 'RIGHT-PS-2-CTD-OP2', 'RIGHT-PS-3N-CTD-OP2']
# LEFT-PS-3N-CLS-OP2: ['LEFT-PS-1-CLS-OP2', 'LEFT-PS-2-CLS-OP2', 'RIGHT-PS-1-CLS-OP2', 'RIGHT-PS-2-CLS-OP2', 'RIGHT-PS-3N-CLS-OP2']
# LEFT-PS-3N-CTD-OP2: ['LEFT-PS-1-CTD-OP2', 'LEFT-PS-2-CTD-OP2', 'RIGHT-PS-1-CTD-OP2', 'RIGHT-PS-2-CTD-OP2', 'RIGHT-PS-3N-CTD-OP2']
# LEFT-PS-3-CLS-OP2: ['LEFT-PS-4N-CLS-OP2', 'LEFT-PS-4-CLS-OP2', 'LEFT-PS-5N-CLS-OP2', 'LEFT-PS-5-CLS-OP2', 'LEFT-PS-6N-CLS-OP2', 'RIGHT-PS-3-CLS-OP2', 'RIGHT-PS-4N-CLS-OP2', 'RIGHT-PS-4-CLS-OP2', 'RIGHT-PS-5N-CLS-OP2', 'RIGHT-PS-5-CLS-OP2', 'RIGHT-PS-6N-CLS-OP2']
# LEFT-PS-3-CTD-OP2: ['LEFT-PS-4N-CTD-OP2', 'LEFT-PS-4-CTD-OP2', 'LEFT-PS-5N-CTD-OP2', 'LEFT-PS-5-CTD-OP2', 'LEFT-PS-6N-CTD-OP2', 'RIGHT-PS-3-CTD-OP2', 'RIGHT-PS-4N-CTD-OP2', 'RIGHT-PS-4-CTD-OP2', 'RIGHT-PS-5N-CTD-OP2', 'RIGHT-PS-5-CTD-OP2', 'RIGHT-PS-6N-CTD-OP2']
# LEFT-PS-4N-CLS-OP2: ['LEFT-PS-3-CLS-OP2', 'LEFT-PS-4-CLS-OP2', 'LEFT-PS-5N-CLS-OP2', 'LEFT-PS-5-CLS-OP2', 'LEFT-PS-6N-CLS-OP2', 'RIGHT-PS-3-CLS-OP2', 'RIGHT-PS-4N-CLS-OP2', 'RIGHT-PS-4-CLS-OP2', 'RIGHT-PS-5N-CLS-OP2', 'RIGHT-PS-5-CLS-OP2', 'RIGHT-PS-6N-CLS-OP2']
# LEFT-PS-4N-CTD-OP2: ['LEFT-PS-3-CTD-OP2', 'LEFT-PS-4-CTD-OP2', 'LEFT-PS-5N-CTD-OP2', 'LEFT-PS-5-CTD-OP2', 'LEFT-PS-6N-CTD-OP2', 'RIGHT-PS-3-CTD-OP2', 'RIGHT-PS-4N-CTD-OP2', 'RIGHT-PS-4-CTD-OP2', 'RIGHT-PS-5N-CTD-OP2', 'RIGHT-PS-5-CTD-OP2', 'RIGHT-PS-6N-CTD-OP2']
# LEFT-PS-4-CLS-OP2: ['LEFT-PS-3-CLS-OP2', 'LEFT-PS-4N-CLS-OP2', 'LEFT-PS-5N-CLS-OP2', 'LEFT-PS-5-CLS-OP2', 'LEFT-PS-6N-CLS-OP2', 'RIGHT-PS-3-CLS-OP2', 'RIGHT-PS-4N-CLS-OP2', 'RIGHT-PS-4-CLS-OP2', 'RIGHT-PS-5N-CLS-OP2', 'RIGHT-PS-5-CLS-OP2', 'RIGHT-PS-6N-CLS-OP2']
# LEFT-PS-4-CTD-OP2: ['LEFT-PS-3-CTD-OP2', 'LEFT-PS-4N-CTD-OP2', 'LEFT-PS-5N-CTD-OP2', 'LEFT-PS-5-CTD-OP2', 'LEFT-PS-6N-CTD-OP2', 'RIGHT-PS-3-CTD-OP2', 'RIGHT-PS-4N-CTD-OP2', 'RIGHT-PS-4-CTD-OP2', 'RIGHT-PS-5N-CTD-OP2', 'RIGHT-PS-5-CTD-OP2', 'RIGHT-PS-6N-CTD-OP2']
# LEFT-PS-5N-CLS-OP2: ['LEFT-PS-3-CLS-OP2', 'LEFT-PS-4N-CLS-OP2', 'LEFT-PS-4-CLS-OP2', 'LEFT-PS-5-CLS-OP2', 'LEFT-PS-6N-CLS-OP2', 'RIGHT-PS-3-CLS-OP2', 'RIGHT-PS-4N-CLS-OP2', 'RIGHT-PS-4-CLS-OP2', 'RIGHT-PS-5N-CLS-OP2', 'RIGHT-PS-5-CLS-OP2', 'RIGHT-PS-6N-CLS-OP2']
# LEFT-PS-5N-CTD-OP2: ['LEFT-PS-3-CTD-OP2', 'LEFT-PS-4N-CTD-OP2', 'LEFT-PS-4-CTD-OP2', 'LEFT-PS-5-CTD-OP2', 'LEFT-PS-6N-CTD-OP2', 'RIGHT-PS-3-CTD-OP2', 'RIGHT-PS-4N-CTD-OP2', 'RIGHT-PS-4-CTD-OP2', 'RIGHT-PS-5N-CTD-OP2', 'RIGHT-PS-5-CTD-OP2', 'RIGHT-PS-6N-CTD-OP2']
# LEFT-PS-5-CLS-OP2: ['LEFT-PS-3-CLS-OP2', 'LEFT-PS-4N-CLS-OP2', 'LEFT-PS-4-CLS-OP2', 'LEFT-PS-5N-CLS-OP2', 'LEFT-PS-6N-CLS-OP2', 'RIGHT-PS-3-CLS-OP2', 'RIGHT-PS-4N-CLS-OP2', 'RIGHT-PS-4-CLS-OP2', 'RIGHT-PS-5N-CLS-OP2', 'RIGHT-PS-5-CLS-OP2', 'RIGHT-PS-6N-CLS-OP2']
# LEFT-PS-5-CTD-OP2: ['LEFT-PS-3-CTD-OP2', 'LEFT-PS-4N-CTD-OP2', 'LEFT-PS-4-CTD-OP2', 'LEFT-PS-5N-CTD-OP2', 'LEFT-PS-6N-CTD-OP2', 'RIGHT-PS-3-CTD-OP2', 'RIGHT-PS-4N-CTD-OP2', 'RIGHT-PS-4-CTD-OP2', 'RIGHT-PS-5N-CTD-OP2', 'RIGHT-PS-5-CTD-OP2', 'RIGHT-PS-6N-CTD-OP2']
# LEFT-PS-6N-CLS-OP2: ['LEFT-PS-3-CLS-OP2', 'LEFT-PS-4N-CLS-OP2', 'LEFT-PS-4-CLS-OP2', 'LEFT-PS-5N-CLS-OP2', 'LEFT-PS-5-CLS-OP2', 'RIGHT-PS-3-CLS-OP2', 'RIGHT-PS-4N-CLS-OP2', 'RIGHT-PS-4-CLS-OP2', 'RIGHT-PS-5N-CLS-OP2', 'RIGHT-PS-5-CLS-OP2', 'RIGHT-PS-6N-CLS-OP2']
# LEFT-PS-6N-CTD-OP2: ['LEFT-PS-3-CTD-OP2', 'LEFT-PS-4N-CTD-OP2', 'LEFT-PS-4-CTD-OP2', 'LEFT-PS-5N-CTD-OP2', 'LEFT-PS-5-CTD-OP2', 'RIGHT-PS-3-CTD-OP2', 'RIGHT-PS-4N-CTD-OP2', 'RIGHT-PS-4-CTD-OP2', 'RIGHT-PS-5N-CTD-OP2', 'RIGHT-PS-5-CTD-OP2', 'RIGHT-PS-6N-CTD-OP2']
# LEFT-PS-6-CLS-OP2: ['LEFT-PS-7-CLS-OP2', 'LEFT-PS-8-CLS-OP2', 'LEFT-PS-9-CLS-OP2', 'LEFT-PS-10-CLS-OP2', 'RIGHT-PS-6-CLS-OP2', 'RIGHT-PS-7-CLS-OP2', 'RIGHT-PS-8-CLS-OP2', 'RIGHT-PS-9-CLS-OP2', 'RIGHT-PS-10-CLS-OP2']
# LEFT-PS-6-CTD-OP2: ['LEFT-PS-7-CTD-OP2', 'LEFT-PS-8-CTD-OP2', 'LEFT-PS-9-CTD-OP2', 'LEFT-PS-10-CTD-OP2', 'RIGHT-PS-6-CTD-OP2', 'RIGHT-PS-7-CTD-OP2', 'RIGHT-PS-8-CTD-OP2', 'RIGHT-PS-9-CTD-OP2', 'RIGHT-PS-10-CTD-OP2']
# LEFT-PS-7-CLS-OP2: ['LEFT-PS-6-CLS-OP2', 'LEFT-PS-8-CLS-OP2', 'LEFT-PS-9-CLS-OP2', 'LEFT-PS-10-CLS-OP2', 'RIGHT-PS-6-CLS-OP2', 'RIGHT-PS-7-CLS-OP2', 'RIGHT-PS-8-CLS-OP2', 'RIGHT-PS-9-CLS-OP2', 'RIGHT-PS-10-CLS-OP2']
# LEFT-PS-7-CTD-OP2: ['LEFT-PS-6-CTD-OP2', 'LEFT-PS-8-CTD-OP2', 'LEFT-PS-9-CTD-OP2', 'LEFT-PS-10-CTD-OP2', 'RIGHT-PS-6-CTD-OP2', 'RIGHT-PS-7-CTD-OP2', 'RIGHT-PS-8-CTD-OP2', 'RIGHT-PS-9-CTD-OP2', 'RIGHT-PS-10-CTD-OP2']
# LEFT-PS-8-CLS-OP2: ['LEFT-PS-6-CLS-OP2', 'LEFT-PS-7-CLS-OP2', 'LEFT-PS-9-CLS-OP2', 'LEFT-PS-10-CLS-OP2', 'RIGHT-PS-6-CLS-OP2', 'RIGHT-PS-7-CLS-OP2', 'RIGHT-PS-8-CLS-OP2', 'RIGHT-PS-9-CLS-OP2', 'RIGHT-PS-10-CLS-OP2']
# LEFT-PS-8-CTD-OP2: ['LEFT-PS-6-CTD-OP2', 'LEFT-PS-7-CTD-OP2', 'LEFT-PS-9-CTD-OP2', 'LEFT-PS-10-CTD-OP2', 'RIGHT-PS-6-CTD-OP2', 'RIGHT-PS-7-CTD-OP2', 'RIGHT-PS-8-CTD-OP2', 'RIGHT-PS-9-CTD-OP2', 'RIGHT-PS-10-CTD-OP2']
# LEFT-PS-9-CLS-OP2: ['LEFT-PS-6-CLS-OP2', 'LEFT-PS-7-CLS-OP2', 'LEFT-PS-8-CLS-OP2', 'LEFT-PS-10-CLS-OP2', 'RIGHT-PS-6-CLS-OP2', 'RIGHT-PS-7-CLS-OP2', 'RIGHT-PS-8-CLS-OP2', 'RIGHT-PS-9-CLS-OP2', 'RIGHT-PS-10-CLS-OP2']
# LEFT-PS-9-CTD-OP2: ['LEFT-PS-6-CTD-OP2', 'LEFT-PS-7-CTD-OP2', 'LEFT-PS-8-CTD-OP2', 'LEFT-PS-10-CTD-OP2', 'RIGHT-PS-6-CTD-OP2', 'RIGHT-PS-7-CTD-OP2', 'RIGHT-PS-8-CTD-OP2', 'RIGHT-PS-9-CTD-OP2', 'RIGHT-PS-10-CTD-OP2']
# LEFT-PS-10-CLS-OP2: ['LEFT-PS-6-CLS-OP2', 'LEFT-PS-7-CLS-OP2', 'LEFT-PS-8-CLS-OP2', 'LEFT-PS-9-CLS-OP2', 'RIGHT-PS-6-CLS-OP2', 'RIGHT-PS-7-CLS-OP2', 'RIGHT-PS-8-CLS-OP2', 'RIGHT-PS-9-CLS-OP2', 'RIGHT-PS-10-CLS-OP2']
# LEFT-PS-10-CTD-OP2: ['LEFT-PS-6-CTD-OP2', 'LEFT-PS-7-CTD-OP2', 'LEFT-PS-8-CTD-OP2', 'LEFT-PS-9-CTD-OP2', 'RIGHT-PS-6-CTD-OP2', 'RIGHT-PS-7-CTD-OP2', 'RIGHT-PS-8-CTD-OP2', 'RIGHT-PS-9-CTD-OP2', 'RIGHT-PS-10-CTD-OP2']
# RIGHT-CR-1-CLS-OP2: ['LEFT-CR-1-CLS-OP2', 'LEFT-CR-1-CTD-OP2', 'LEFT-CR-2-CLS-OP2', 'LEFT-CR-2-CTD-OP2', 'LEFT-CR-3N-CLS-OP2', 'LEFT-CR-3N-CTD-OP2', 'RIGHT-CR-1-CTD-OP2', 'RIGHT-CR-2-CLS-OP2', 'RIGHT-CR-2-CTD-OP2', 'RIGHT-CR-3N-CLS-OP2', 'RIGHT-CR-3N-CTD-OP2']
# RIGHT-CR-1-CTD-OP2: ['LEFT-CR-1-CLS-OP2', 'LEFT-CR-1-CTD-OP2', 'LEFT-CR-2-CLS-OP2', 'LEFT-CR-2-CTD-OP2', 'LEFT-CR-3N-CLS-OP2', 'LEFT-CR-3N-CTD-OP2', 'RIGHT-CR-1-CLS-OP2', 'RIGHT-CR-2-CLS-OP2', 'RIGHT-CR-2-CTD-OP2', 'RIGHT-CR-3N-CLS-OP2', 'RIGHT-CR-3N-CTD-OP2']
# RIGHT-CR-2-CLS-OP2: ['LEFT-CR-1-CLS-OP2', 'LEFT-CR-1-CTD-OP2', 'LEFT-CR-2-CLS-OP2', 'LEFT-CR-2-CTD-OP2', 'LEFT-CR-3N-CLS-OP2', 'LEFT-CR-3N-CTD-OP2', 'RIGHT-CR-1-CLS-OP2', 'RIGHT-CR-1-CTD-OP2', 'RIGHT-CR-2-CTD-OP2', 'RIGHT-CR-3N-CLS-OP2', 'RIGHT-CR-3N-CTD-OP2']
# RIGHT-CR-2-CTD-OP2: ['LEFT-CR-1-CLS-OP2', 'LEFT-CR-1-CTD-OP2', 'LEFT-CR-2-CLS-OP2', 'LEFT-CR-2-CTD-OP2', 'LEFT-CR-3N-CLS-OP2', 'LEFT-CR-3N-CTD-OP2', 'RIGHT-CR-1-CLS-OP2', 'RIGHT-CR-1-CTD-OP2', 'RIGHT-CR-2-CLS-OP2', 'RIGHT-CR-3N-CLS-OP2', 'RIGHT-CR-3N-CTD-OP2']
# RIGHT-CR-3N-CLS-OP2: ['LEFT-CR-1-CLS-OP2', 'LEFT-CR-1-CTD-OP2', 'LEFT-CR-2-CLS-OP2', 'LEFT-CR-2-CTD-OP2', 'LEFT-CR-3N-CLS-OP2', 'LEFT-CR-3N-CTD-OP2', 'RIGHT-CR-1-CLS-OP2', 'RIGHT-CR-1-CTD-OP2', 'RIGHT-CR-2-CLS-OP2', 'RIGHT-CR-2-CTD-OP2', 'RIGHT-CR-3N-CTD-OP2']
# RIGHT-CR-3N-CTD-OP2: ['LEFT-CR-1-CLS-OP2', 'LEFT-CR-1-CTD-OP2', 'LEFT-CR-2-CLS-OP2', 'LEFT-CR-2-CTD-OP2', 'LEFT-CR-3N-CLS-OP2', 'LEFT-CR-3N-CTD-OP2', 'RIGHT-CR-1-CLS-OP2', 'RIGHT-CR-1-CTD-OP2', 'RIGHT-CR-2-CLS-OP2', 'RIGHT-CR-2-CTD-OP2', 'RIGHT-CR-3N-CLS-OP2']
# RIGHT-CR-3-CLS-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# RIGHT-CR-3-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# RIGHT-CR-4N-CLS-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# RIGHT-CR-4N-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# RIGHT-CR-4-CLS-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# RIGHT-CR-4-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# RIGHT-CR-5N-CLS-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# RIGHT-CR-5N-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# RIGHT-CR-5-CLS-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# RIGHT-CR-5-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-6N-CLS-OP2', 'RIGHT-CR-6N-CTD-OP2']
# RIGHT-CR-6N-CLS-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CTD-OP2']
# RIGHT-CR-6N-CTD-OP2: ['LEFT-CR-3-CLS-OP2', 'LEFT-CR-3-CTD-OP2', 'LEFT-CR-4N-CLS-OP2', 'LEFT-CR-4N-CTD-OP2', 'LEFT-CR-4-CLS-OP2', 'LEFT-CR-4-CTD-OP2', 'LEFT-CR-5N-CLS-OP2', 'LEFT-CR-5N-CTD-OP2', 'LEFT-CR-5-CLS-OP2', 'LEFT-CR-5-CTD-OP2', 'LEFT-CR-6N-CLS-OP2', 'LEFT-CR-6N-CTD-OP2', 'RIGHT-CR-3-CLS-OP2', 'RIGHT-CR-3-CTD-OP2', 'RIGHT-CR-4N-CLS-OP2', 'RIGHT-CR-4N-CTD-OP2', 'RIGHT-CR-4-CLS-OP2', 'RIGHT-CR-4-CTD-OP2', 'RIGHT-CR-5N-CLS-OP2', 'RIGHT-CR-5N-CTD-OP2', 'RIGHT-CR-5-CLS-OP2', 'RIGHT-CR-5-CTD-OP2', 'RIGHT-CR-6N-CLS-OP2']
# RIGHT-CR-6-CLS-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# RIGHT-CR-6-CTD-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# RIGHT-CR-7-CLS-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# RIGHT-CR-7-CTD-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# RIGHT-CR-8-CLS-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# RIGHT-CR-8-CTD-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# RIGHT-CR-9-CLS-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# RIGHT-CR-9-CTD-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-10-CLS-OP2', 'RIGHT-CR-10-CTD-OP2']
# RIGHT-CR-10-CLS-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CTD-OP2']
# RIGHT-CR-10-CTD-OP2: ['LEFT-CR-6-CLS-OP2', 'LEFT-CR-6-CTD-OP2', 'LEFT-CR-7-CLS-OP2', 'LEFT-CR-7-CTD-OP2', 'LEFT-CR-8-CLS-OP2', 'LEFT-CR-8-CTD-OP2', 'LEFT-CR-9-CLS-OP2', 'LEFT-CR-9-CTD-OP2', 'LEFT-CR-10-CLS-OP2', 'LEFT-CR-10-CTD-OP2', 'RIGHT-CR-6-CLS-OP2', 'RIGHT-CR-6-CTD-OP2', 'RIGHT-CR-7-CLS-OP2', 'RIGHT-CR-7-CTD-OP2', 'RIGHT-CR-8-CLS-OP2', 'RIGHT-CR-8-CTD-OP2', 'RIGHT-CR-9-CLS-OP2', 'RIGHT-CR-9-CTD-OP2', 'RIGHT-CR-10-CLS-OP2']
# RIGHT-PS-1-CLS-OP2: ['LEFT-PS-1-CLS-OP2', 'LEFT-PS-2-CLS-OP2', 'LEFT-PS-3N-CLS-OP2', 'RIGHT-PS-2-CLS-OP2', 'RIGHT-PS-3N-CLS-OP2']
# RIGHT-PS-1-CTD-OP2: ['LEFT-PS-1-CTD-OP2', 'LEFT-PS-2-CTD-OP2', 'LEFT-PS-3N-CTD-OP2', 'RIGHT-PS-2-CTD-OP2', 'RIGHT-PS-3N-CTD-OP2']
# RIGHT-PS-2-CLS-OP2: ['LEFT-PS-1-CLS-OP2', 'LEFT-PS-2-CLS-OP2', 'LEFT-PS-3N-CLS-OP2', 'RIGHT-PS-1-CLS-OP2', 'RIGHT-PS-3N-CLS-OP2']
# RIGHT-PS-2-CTD-OP2: ['LEFT-PS-1-CTD-OP2', 'LEFT-PS-2-CTD-OP2', 'LEFT-PS-3N-CTD-OP2', 'RIGHT-PS-1-CTD-OP2', 'RIGHT-PS-3N-CTD-OP2']
# RIGHT-PS-3N-CLS-OP2: ['LEFT-PS-1-CLS-OP2', 'LEFT-PS-2-CLS-OP2', 'LEFT-PS-3N-CLS-OP2', 'RIGHT-PS-1-CLS-OP2', 'RIGHT-PS-2-CLS-OP2']
# RIGHT-PS-3N-CTD-OP2: ['LEFT-PS-1-CTD-OP2', 'LEFT-PS-2-CTD-OP2', 'LEFT-PS-3N-CTD-OP2', 'RIGHT-PS-1-CTD-OP2', 'RIGHT-PS-2-CTD-OP2']
# RIGHT-PS-3-CLS-OP2: ['LEFT-PS-3-CLS-OP2', 'LEFT-PS-4N-CLS-OP2', 'LEFT-PS-4-CLS-OP2', 'LEFT-PS-5N-CLS-OP2', 'LEFT-PS-5-CLS-OP2', 'LEFT-PS-6N-CLS-OP2', 'RIGHT-PS-4N-CLS-OP2', 'RIGHT-PS-4-CLS-OP2', 'RIGHT-PS-5N-CLS-OP2', 'RIGHT-PS-5-CLS-OP2', 'RIGHT-PS-6N-CLS-OP2']
# RIGHT-PS-3-CTD-OP2: ['LEFT-PS-3-CTD-OP2', 'LEFT-PS-4N-CTD-OP2', 'LEFT-PS-4-CTD-OP2', 'LEFT-PS-5N-CTD-OP2', 'LEFT-PS-5-CTD-OP2', 'LEFT-PS-6N-CTD-OP2', 'RIGHT-PS-4N-CTD-OP2', 'RIGHT-PS-4-CTD-OP2', 'RIGHT-PS-5N-CTD-OP2', 'RIGHT-PS-5-CTD-OP2', 'RIGHT-PS-6N-CTD-OP2']
# RIGHT-PS-4N-CLS-OP2: ['LEFT-PS-3-CLS-OP2', 'LEFT-PS-4N-CLS-OP2', 'LEFT-PS-4-CLS-OP2', 'LEFT-PS-5N-CLS-OP2', 'LEFT-PS-5-CLS-OP2', 'LEFT-PS-6N-CLS-OP2', 'RIGHT-PS-3-CLS-OP2', 'RIGHT-PS-4-CLS-OP2', 'RIGHT-PS-5N-CLS-OP2', 'RIGHT-PS-5-CLS-OP2', 'RIGHT-PS-6N-CLS-OP2']
# RIGHT-PS-4N-CTD-OP2: ['LEFT-PS-3-CTD-OP2', 'LEFT-PS-4N-CTD-OP2', 'LEFT-PS-4-CTD-OP2', 'LEFT-PS-5N-CTD-OP2', 'LEFT-PS-5-CTD-OP2', 'LEFT-PS-6N-CTD-OP2', 'RIGHT-PS-3-CTD-OP2', 'RIGHT-PS-4-CTD-OP2', 'RIGHT-PS-5N-CTD-OP2', 'RIGHT-PS-5-CTD-OP2', 'RIGHT-PS-6N-CTD-OP2']
# RIGHT-PS-4-CLS-OP2: ['LEFT-PS-3-CLS-OP2', 'LEFT-PS-4N-CLS-OP2', 'LEFT-PS-4-CLS-OP2', 'LEFT-PS-5N-CLS-OP2', 'LEFT-PS-5-CLS-OP2', 'LEFT-PS-6N-CLS-OP2', 'RIGHT-PS-3-CLS-OP2', 'RIGHT-PS-4N-CLS-OP2', 'RIGHT-PS-5N-CLS-OP2', 'RIGHT-PS-5-CLS-OP2', 'RIGHT-PS-6N-CLS-OP2']
# RIGHT-PS-4-CTD-OP2: ['LEFT-PS-3-CTD-OP2', 'LEFT-PS-4N-CTD-OP2', 'LEFT-PS-4-CTD-OP2', 'LEFT-PS-5N-CTD-OP2', 'LEFT-PS-5-CTD-OP2', 'LEFT-PS-6N-CTD-OP2', 'RIGHT-PS-3-CTD-OP2', 'RIGHT-PS-4N-CTD-OP2', 'RIGHT-PS-5N-CTD-OP2', 'RIGHT-PS-5-CTD-OP2', 'RIGHT-PS-6N-CTD-OP2']
# RIGHT-PS-5N-CLS-OP2: ['LEFT-PS-3-CLS-OP2', 'LEFT-PS-4N-CLS-OP2', 'LEFT-PS-4-CLS-OP2', 'LEFT-PS-5N-CLS-OP2', 'LEFT-PS-5-CLS-OP2', 'LEFT-PS-6N-CLS-OP2', 'RIGHT-PS-3-CLS-OP2', 'RIGHT-PS-4N-CLS-OP2', 'RIGHT-PS-4-CLS-OP2', 'RIGHT-PS-5-CLS-OP2', 'RIGHT-PS-6N-CLS-OP2']
# RIGHT-PS-5N-CTD-OP2: ['LEFT-PS-3-CTD-OP2', 'LEFT-PS-4N-CTD-OP2', 'LEFT-PS-4-CTD-OP2', 'LEFT-PS-5N-CTD-OP2', 'LEFT-PS-5-CTD-OP2', 'LEFT-PS-6N-CTD-OP2', 'RIGHT-PS-3-CTD-OP2', 'RIGHT-PS-4N-CTD-OP2', 'RIGHT-PS-4-CTD-OP2', 'RIGHT-PS-5-CTD-OP2', 'RIGHT-PS-6N-CTD-OP2']
# RIGHT-PS-5-CLS-OP2: ['LEFT-PS-3-CLS-OP2', 'LEFT-PS-4N-CLS-OP2', 'LEFT-PS-4-CLS-OP2', 'LEFT-PS-5N-CLS-OP2', 'LEFT-PS-5-CLS-OP2', 'LEFT-PS-6N-CLS-OP2', 'RIGHT-PS-3-CLS-OP2', 'RIGHT-PS-4N-CLS-OP2', 'RIGHT-PS-4-CLS-OP2', 'RIGHT-PS-5N-CLS-OP2', 'RIGHT-PS-6N-CLS-OP2']
# RIGHT-PS-5-CTD-OP2: ['LEFT-PS-3-CTD-OP2', 'LEFT-PS-4N-CTD-OP2', 'LEFT-PS-4-CTD-OP2', 'LEFT-PS-5N-CTD-OP2', 'LEFT-PS-5-CTD-OP2', 'LEFT-PS-6N-CTD-OP2', 'RIGHT-PS-3-CTD-OP2', 'RIGHT-PS-4N-CTD-OP2', 'RIGHT-PS-4-CTD-OP2', 'RIGHT-PS-5N-CTD-OP2', 'RIGHT-PS-6N-CTD-OP2']
# RIGHT-PS-6N-CLS-OP2: ['LEFT-PS-3-CLS-OP2', 'LEFT-PS-4N-CLS-OP2', 'LEFT-PS-4-CLS-OP2', 'LEFT-PS-5N-CLS-OP2', 'LEFT-PS-5-CLS-OP2', 'LEFT-PS-6N-CLS-OP2', 'RIGHT-PS-3-CLS-OP2', 'RIGHT-PS-4N-CLS-OP2', 'RIGHT-PS-4-CLS-OP2', 'RIGHT-PS-5N-CLS-OP2', 'RIGHT-PS-5-CLS-OP2']
# RIGHT-PS-6N-CTD-OP2: ['LEFT-PS-3-CTD-OP2', 'LEFT-PS-4N-CTD-OP2', 'LEFT-PS-4-CTD-OP2', 'LEFT-PS-5N-CTD-OP2', 'LEFT-PS-5-CTD-OP2', 'LEFT-PS-6N-CTD-OP2', 'RIGHT-PS-3-CTD-OP2', 'RIGHT-PS-4N-CTD-OP2', 'RIGHT-PS-4-CTD-OP2', 'RIGHT-PS-5N-CTD-OP2', 'RIGHT-PS-5-CTD-OP2']
# RIGHT-PS-6-CLS-OP2: ['LEFT-PS-6-CLS-OP2', 'LEFT-PS-7-CLS-OP2', 'LEFT-PS-8-CLS-OP2', 'LEFT-PS-9-CLS-OP2', 'LEFT-PS-10-CLS-OP2', 'RIGHT-PS-7-CLS-OP2', 'RIGHT-PS-8-CLS-OP2', 'RIGHT-PS-9-CLS-OP2', 'RIGHT-PS-10-CLS-OP2']
# RIGHT-PS-6-CTD-OP2: ['LEFT-PS-6-CTD-OP2', 'LEFT-PS-7-CTD-OP2', 'LEFT-PS-8-CTD-OP2', 'LEFT-PS-9-CTD-OP2', 'LEFT-PS-10-CTD-OP2', 'RIGHT-PS-7-CTD-OP2', 'RIGHT-PS-8-CTD-OP2', 'RIGHT-PS-9-CTD-OP2', 'RIGHT-PS-10-CTD-OP2']
# RIGHT-PS-7-CLS-OP2: ['LEFT-PS-6-CLS-OP2', 'LEFT-PS-7-CLS-OP2', 'LEFT-PS-8-CLS-OP2', 'LEFT-PS-9-CLS-OP2', 'LEFT-PS-10-CLS-OP2', 'RIGHT-PS-6-CLS-OP2', 'RIGHT-PS-8-CLS-OP2', 'RIGHT-PS-9-CLS-OP2', 'RIGHT-PS-10-CLS-OP2']
# RIGHT-PS-7-CTD-OP2: ['LEFT-PS-6-CTD-OP2', 'LEFT-PS-7-CTD-OP2', 'LEFT-PS-8-CTD-OP2', 'LEFT-PS-9-CTD-OP2', 'LEFT-PS-10-CTD-OP2', 'RIGHT-PS-6-CTD-OP2', 'RIGHT-PS-8-CTD-OP2', 'RIGHT-PS-9-CTD-OP2', 'RIGHT-PS-10-CTD-OP2']
# RIGHT-PS-8-CLS-OP2: ['LEFT-PS-6-CLS-OP2', 'LEFT-PS-7-CLS-OP2', 'LEFT-PS-8-CLS-OP2', 'LEFT-PS-9-CLS-OP2', 'LEFT-PS-10-CLS-OP2', 'RIGHT-PS-6-CLS-OP2', 'RIGHT-PS-7-CLS-OP2', 'RIGHT-PS-9-CLS-OP2', 'RIGHT-PS-10-CLS-OP2']
# RIGHT-PS-8-CTD-OP2: ['LEFT-PS-6-CTD-OP2', 'LEFT-PS-7-CTD-OP2', 'LEFT-PS-8-CTD-OP2', 'LEFT-PS-9-CTD-OP2', 'LEFT-PS-10-CTD-OP2', 'RIGHT-PS-6-CTD-OP2', 'RIGHT-PS-7-CTD-OP2', 'RIGHT-PS-9-CTD-OP2', 'RIGHT-PS-10-CTD-OP2']
# RIGHT-PS-9-CLS-OP2: ['LEFT-PS-6-CLS-OP2', 'LEFT-PS-7-CLS-OP2', 'LEFT-PS-8-CLS-OP2', 'LEFT-PS-9-CLS-OP2', 'LEFT-PS-10-CLS-OP2', 'RIGHT-PS-6-CLS-OP2', 'RIGHT-PS-7-CLS-OP2', 'RIGHT-PS-8-CLS-OP2', 'RIGHT-PS-10-CLS-OP2']
# RIGHT-PS-9-CTD-OP2: ['LEFT-PS-6-CTD-OP2', 'LEFT-PS-7-CTD-OP2', 'LEFT-PS-8-CTD-OP2', 'LEFT-PS-9-CTD-OP2', 'LEFT-PS-10-CTD-OP2', 'RIGHT-PS-6-CTD-OP2', 'RIGHT-PS-7-CTD-OP2', 'RIGHT-PS-8-CTD-OP2', 'RIGHT-PS-10-CTD-OP2']
# RIGHT-PS-10-CLS-OP2: ['LEFT-PS-6-CLS-OP2', 'LEFT-PS-7-CLS-OP2', 'LEFT-PS-8-CLS-OP2', 'LEFT-PS-9-CLS-OP2', 'LEFT-PS-10-CLS-OP2', 'RIGHT-PS-6-CLS-OP2', 'RIGHT-PS-7-CLS-OP2', 'RIGHT-PS-8-CLS-OP2', 'RIGHT-PS-9-CLS-OP2']
# RIGHT-PS-10-CTD-OP2: ['LEFT-PS-6-CTD-OP2', 'LEFT-PS-7-CTD-OP2', 'LEFT-PS-8-CTD-OP2', 'LEFT-PS-9-CTD-OP2', 'LEFT-PS-10-CTD-OP2', 'RIGHT-PS-6-CTD-OP2', 'RIGHT-PS-7-CTD-OP2', 'RIGHT-PS-8-CTD-OP2', 'RIGHT-PS-9-CTD-OP2']

# %%
compatibility_dict['LEFT-CR-7-CLS-OP2']
# Out:
# ['LEFT-CR-6-CLS-OP2',
#  'LEFT-CR-6-CTD-OP2',
#  'LEFT-CR-7-CTD-OP2',
#  'LEFT-CR-8-CLS-OP2',
#  'LEFT-CR-8-CTD-OP2',
#  'LEFT-CR-9-CLS-OP2',
#  'LEFT-CR-9-CTD-OP2',
#  'LEFT-CR-10-CLS-OP2',
#  'LEFT-CR-10-CTD-OP2',
#  'RIGHT-CR-6-CLS-OP2',
#  'RIGHT-CR-6-CTD-OP2',
#  'RIGHT-CR-7-CLS-OP2',
#  'RIGHT-CR-7-CTD-OP2',
#  'RIGHT-CR-8-CLS-OP2',
#  'RIGHT-CR-8-CTD-OP2',
#  'RIGHT-CR-9-CLS-OP2',
#  'RIGHT-CR-9-CTD-OP2',
#  'RIGHT-CR-10-CLS-OP2',
#  'RIGHT-CR-10-CTD-OP2']

# %% [markdown]
# ## Test

# %%
'LEFT-CR-2-CLS-OP2' in compatibility_dict['LEFT-CR-1-CLS-OP2']
# Out:
# True

# %%
'LEFT-CR-2-CLS-OP2' in compatibility_dict['LEFT-CR-9-CLS-OP2']
# Out:
# False

# %%
input_repr_dict = catalog.load('input_repr_dict')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 input_repr_dict = catalog.load('input_repr_dict')
#
# NameError: name 'catalog' is not defined

# %% [markdown]
# ## Save the result

# %%
import pickle

# Save the compatibility dictionary as a pickle file
with open('../data/05_model_input/compatibility_dict_op2.pkl', 'wb') as f:
    pickle.dump(compatibility_dict, f)

# %% [markdown]
# ## OP 1

# %%
import itertools
import pickle

# Define attributes
sizes = ["1", "2", "3N", "3", "4N", "4", "5N", "5", "6N", "6", "7", "8", "9", "10"]
orientations = ["LEFT", "RIGHT"]
types = ["CR", "PS"]
cementing_methods = ["CLS", "CTD"]
operation = ["OP1"]

# Generate all possible part IDs
part_ids_op1 = [
    f"{orientation}-{type}-{size}-{cementing}-{op}"
    for orientation, type, size, cementing, op in itertools.product(orientations, types, sizes, cementing_methods, operation)
]

# Create compatibility dictionary for OP1
compatibility_dict_op1 = {}

for part_id in part_ids_op1:
    orientation, type, size, cementing, op = part_id.split('-')
    
    compatible_parts = []
    
    for other_part_id in part_ids_op1:
        if other_part_id == part_id:
            continue
        
        other_orientation, other_type, other_size, other_cementing, other_op = other_part_id.split('-')
        
        if other_op != "OP1":
            continue
        
        if size == other_size and cementing == other_cementing:
            compatible_parts.append(other_part_id)
    
    compatibility_dict_op1[part_id] = compatible_parts

# %%
compatibility_dict_op1
# Out:
# {'LEFT-CR-1-CLS-OP1': ['LEFT-PS-1-CLS-OP1',
#   'RIGHT-CR-1-CLS-OP1',
#   'RIGHT-PS-1-CLS-OP1'],
#  'LEFT-CR-1-CTD-OP1': ['LEFT-PS-1-CTD-OP1',
#   'RIGHT-CR-1-CTD-OP1',
#   'RIGHT-PS-1-CTD-OP1'],
#  'LEFT-CR-2-CLS-OP1': ['LEFT-PS-2-CLS-OP1',
#   'RIGHT-CR-2-CLS-OP1',
#   'RIGHT-PS-2-CLS-OP1'],
#  'LEFT-CR-2-CTD-OP1': ['LEFT-PS-2-CTD-OP1',
#   'RIGHT-CR-2-CTD-OP1',
#   'RIGHT-PS-2-CTD-OP1'],
#  'LEFT-CR-3N-CLS-OP1': ['LEFT-PS-3N-CLS-OP1',
#   'RIGHT-CR-3N-CLS-OP1',
#   'RIGHT-PS-3N-CLS-OP1'],
#  'LEFT-CR-3N-CTD-OP1': ['LEFT-PS-3N-CTD-OP1',
#   'RIGHT-CR-3N-CTD-OP1',
#   'RIGHT-PS-3N-CTD-OP1'],
#  'LEFT-CR-3-CLS-OP1': ['LEFT-PS-3-CLS-OP1',
#   'RIGHT-CR-3-CLS-OP1',
#   'RIGHT-PS-3-CLS-OP1'],
#  'LEFT-CR-3-CTD-OP1': ['LEFT-PS-3-CTD-OP1',
#   'RIGHT-CR-3-CTD-OP1',
#   'RIGHT-PS-3-CTD-OP1'],
#  'LEFT-CR-4N-CLS-OP1': ['LEFT-PS-4N-CLS-OP1',
#   'RIGHT-CR-4N-CLS-OP1',
#   'RIGHT-PS-4N-CLS-OP1'],
#  'LEFT-CR-4N-CTD-OP1': ['LEFT-PS-4N-CTD-OP1',
#   'RIGHT-CR-4N-CTD-OP1',
#   'RIGHT-PS-4N-CTD-OP1'],
#  'LEFT-CR-4-CLS-OP1': ['LEFT-PS-4-CLS-OP1',
#   'RIGHT-CR-4-CLS-OP1',
#   'RIGHT-PS-4-CLS-OP1'],
#  'LEFT-CR-4-CTD-OP1': ['LEFT-PS-4-CTD-OP1',
#   'RIGHT-CR-4-CTD-OP1',
#   'RIGHT-PS-4-CTD-OP1'],
#  'LEFT-CR-5N-CLS-OP1': ['LEFT-PS-5N-CLS-OP1',
#   'RIGHT-CR-5N-CLS-OP1',
#   'RIGHT-PS-5N-CLS-OP1'],
#  'LEFT-CR-5N-CTD-OP1': ['LEFT-PS-5N-CTD-OP1',
#   'RIGHT-CR-5N-CTD-OP1',
#   'RIGHT-PS-5N-CTD-OP1'],
#  'LEFT-CR-5-CLS-OP1': ['LEFT-PS-5-CLS-OP1',
#   'RIGHT-CR-5-CLS-OP1',
#   'RIGHT-PS-5-CLS-OP1'],
#  'LEFT-CR-5-CTD-OP1': ['LEFT-PS-5-CTD-OP1',
#   'RIGHT-CR-5-CTD-OP1',
#   'RIGHT-PS-5-CTD-OP1'],
#  'LEFT-CR-6N-CLS-OP1': ['LEFT-PS-6N-CLS-OP1',
#   'RIGHT-CR-6N-CLS-OP1',
#   'RIGHT-PS-6N-CLS-OP1'],
#  'LEFT-CR-6N-CTD-OP1': ['LEFT-PS-6N-CTD-OP1',
#   'RIGHT-CR-6N-CTD-OP1',
#   'RIGHT-PS-6N-CTD-OP1'],
#  'LEFT-CR-6-CLS-OP1': ['LEFT-PS-6-CLS-OP1',
#   'RIGHT-CR-6-CLS-OP1',
#   'RIGHT-PS-6-CLS-OP1'],
#  'LEFT-CR-6-CTD-OP1': ['LEFT-PS-6-CTD-OP1',
#   'RIGHT-CR-6-CTD-OP1',
#   'RIGHT-PS-6-CTD-OP1'],
#  'LEFT-CR-7-CLS-OP1': ['LEFT-PS-7-CLS-OP1',
#   'RIGHT-CR-7-CLS-OP1',
#   'RIGHT-PS-7-CLS-OP1'],
#  'LEFT-CR-7-CTD-OP1': ['LEFT-PS-7-CTD-OP1',
#   'RIGHT-CR-7-CTD-OP1',
#   'RIGHT-PS-7-CTD-OP1'],
#  'LEFT-CR-8-CLS-OP1': ['LEFT-PS-8-CLS-OP1',
#   'RIGHT-CR-8-CLS-OP1',
#   'RIGHT-PS-8-CLS-OP1'],
#  'LEFT-CR-8-CTD-OP1': ['LEFT-PS-8-CTD-OP1',
#   'RIGHT-CR-8-CTD-OP1',
#   'RIGHT-PS-8-CTD-OP1'],
#  'LEFT-CR-9-CLS-OP1': ['LEFT-PS-9-CLS-OP1',
#   'RIGHT-CR-9-CLS-OP1',
#   'RIGHT-PS-9-CLS-OP1'],
#  'LEFT-CR-9-CTD-OP1': ['LEFT-PS-9-CTD-OP1',
#   'RIGHT-CR-9-CTD-OP1',
#   'RIGHT-PS-9-CTD-OP1'],
#  'LEFT-CR-10-CLS-OP1': ['LEFT-PS-10-CLS-OP1',
#   'RIGHT-CR-10-CLS-OP1',
#   'RIGHT-PS-10-CLS-OP1'],
#  'LEFT-CR-10-CTD-OP1': ['LEFT-PS-10-CTD-OP1',
#   'RIGHT-CR-10-CTD-OP1',
#   'RIGHT-PS-10-CTD-OP1'],
#  'LEFT-PS-1-CLS-OP1': ['LEFT-CR-1-CLS-OP1',
#   'RIGHT-CR-1-CLS-OP1',
#   'RIGHT-PS-1-CLS-OP1'],
#  'LEFT-PS-1-CTD-OP1': ['LEFT-CR-1-CTD-OP1',
#   'RIGHT-CR-1-CTD-OP1',
#   'RIGHT-PS-1-CTD-OP1'],
#  'LEFT-PS-2-CLS-OP1': ['LEFT-CR-2-CLS-OP1',
#   'RIGHT-CR-2-CLS-OP1',
#   'RIGHT-PS-2-CLS-OP1'],
#  'LEFT-PS-2-CTD-OP1': ['LEFT-CR-2-CTD-OP1',
#   'RIGHT-CR-2-CTD-OP1',
#   'RIGHT-PS-2-CTD-OP1'],
#  'LEFT-PS-3N-CLS-OP1': ['LEFT-CR-3N-CLS-OP1',
#   'RIGHT-CR-3N-CLS-OP1',
#   'RIGHT-PS-3N-CLS-OP1'],
#  'LEFT-PS-3N-CTD-OP1': ['LEFT-CR-3N-CTD-OP1',
#   'RIGHT-CR-3N-CTD-OP1',
#   'RIGHT-PS-3N-CTD-OP1'],
#  'LEFT-PS-3-CLS-OP1': ['LEFT-CR-3-CLS-OP1',
#   'RIGHT-CR-3-CLS-OP1',
#   'RIGHT-PS-3-CLS-OP1'],
#  'LEFT-PS-3-CTD-OP1': ['LEFT-CR-3-CTD-OP1',
#   'RIGHT-CR-3-CTD-OP1',
#   'RIGHT-PS-3-CTD-OP1'],
#  'LEFT-PS-4N-CLS-OP1': ['LEFT-CR-4N-CLS-OP1',
#   'RIGHT-CR-4N-CLS-OP1',
#   'RIGHT-PS-4N-CLS-OP1'],
#  'LEFT-PS-4N-CTD-OP1': ['LEFT-CR-4N-CTD-OP1',
#   'RIGHT-CR-4N-CTD-OP1',
#   'RIGHT-PS-4N-CTD-OP1'],
#  'LEFT-PS-4-CLS-OP1': ['LEFT-CR-4-CLS-OP1',
#   'RIGHT-CR-4-CLS-OP1',
#   'RIGHT-PS-4-CLS-OP1'],
#  'LEFT-PS-4-CTD-OP1': ['LEFT-CR-4-CTD-OP1',
#   'RIGHT-CR-4-CTD-OP1',
#   'RIGHT-PS-4-CTD-OP1'],
#  'LEFT-PS-5N-CLS-OP1': ['LEFT-CR-5N-CLS-OP1',
#   'RIGHT-CR-5N-CLS-OP1',
#   'RIGHT-PS-5N-CLS-OP1'],
#  'LEFT-PS-5N-CTD-OP1': ['LEFT-CR-5N-CTD-OP1',
#   'RIGHT-CR-5N-CTD-OP1',
#   'RIGHT-PS-5N-CTD-OP1'],
#  'LEFT-PS-5-CLS-OP1': ['LEFT-CR-5-CLS-OP1',
#   'RIGHT-CR-5-CLS-OP1',
#   'RIGHT-PS-5-CLS-OP1'],
#  'LEFT-PS-5-CTD-OP1': ['LEFT-CR-5-CTD-OP1',
#   'RIGHT-CR-5-CTD-OP1',
#   'RIGHT-PS-5-CTD-OP1'],
#  'LEFT-PS-6N-CLS-OP1': ['LEFT-CR-6N-CLS-OP1',
#   'RIGHT-CR-6N-CLS-OP1',
#   'RIGHT-PS-6N-CLS-OP1'],
#  'LEFT-PS-6N-CTD-OP1': ['LEFT-CR-6N-CTD-OP1',
#   'RIGHT-CR-6N-CTD-OP1',
#   'RIGHT-PS-6N-CTD-OP1'],
#  'LEFT-PS-6-CLS-OP1': ['LEFT-CR-6-CLS-OP1',
#   'RIGHT-CR-6-CLS-OP1',
#   'RIGHT-PS-6-CLS-OP1'],
#  'LEFT-PS-6-CTD-OP1': ['LEFT-CR-6-CTD-OP1',
#   'RIGHT-CR-6-CTD-OP1',
#   'RIGHT-PS-6-CTD-OP1'],
#  'LEFT-PS-7-CLS-OP1': ['LEFT-CR-7-CLS-OP1',
#   'RIGHT-CR-7-CLS-OP1',
#   'RIGHT-PS-7-CLS-OP1'],
#  'LEFT-PS-7-CTD-OP1': ['LEFT-CR-7-CTD-OP1',
#   'RIGHT-CR-7-CTD-OP1',
#   'RIGHT-PS-7-CTD-OP1'],
#  'LEFT-PS-8-CLS-OP1': ['LEFT-CR-8-CLS-OP1',
#   'RIGHT-CR-8-CLS-OP1',
#   'RIGHT-PS-8-CLS-OP1'],
#  'LEFT-PS-8-CTD-OP1': ['LEFT-CR-8-CTD-OP1',
#   'RIGHT-CR-8-CTD-OP1',
#   'RIGHT-PS-8-CTD-OP1'],
#  'LEFT-PS-9-CLS-OP1': ['LEFT-CR-9-CLS-OP1',
#   'RIGHT-CR-9-CLS-OP1',
#   'RIGHT-PS-9-CLS-OP1'],
#  'LEFT-PS-9-CTD-OP1': ['LEFT-CR-9-CTD-OP1',
#   'RIGHT-CR-9-CTD-OP1',
#   'RIGHT-PS-9-CTD-OP1'],
#  'LEFT-PS-10-CLS-OP1': ['LEFT-CR-10-CLS-OP1',
#   'RIGHT-CR-10-CLS-OP1',
#   'RIGHT-PS-10-CLS-OP1'],
#  'LEFT-PS-10-CTD-OP1': ['LEFT-CR-10-CTD-OP1',
#   'RIGHT-CR-10-CTD-OP1',
#   'RIGHT-PS-10-CTD-OP1'],
#  'RIGHT-CR-1-CLS-OP1': ['LEFT-CR-1-CLS-OP1',
#   'LEFT-PS-1-CLS-OP1',
#   'RIGHT-PS-1-CLS-OP1'],
#  'RIGHT-CR-1-CTD-OP1': ['LEFT-CR-1-CTD-OP1',
#   'LEFT-PS-1-CTD-OP1',
#   'RIGHT-PS-1-CTD-OP1'],
#  'RIGHT-CR-2-CLS-OP1': ['LEFT-CR-2-CLS-OP1',
#   'LEFT-PS-2-CLS-OP1',
#   'RIGHT-PS-2-CLS-OP1'],
#  'RIGHT-CR-2-CTD-OP1': ['LEFT-CR-2-CTD-OP1',
#   'LEFT-PS-2-CTD-OP1',
#   'RIGHT-PS-2-CTD-OP1'],
#  'RIGHT-CR-3N-CLS-OP1': ['LEFT-CR-3N-CLS-OP1',
#   'LEFT-PS-3N-CLS-OP1',
#   'RIGHT-PS-3N-CLS-OP1'],
#  'RIGHT-CR-3N-CTD-OP1': ['LEFT-CR-3N-CTD-OP1',
#   'LEFT-PS-3N-CTD-OP1',
#   'RIGHT-PS-3N-CTD-OP1'],
#  'RIGHT-CR-3-CLS-OP1': ['LEFT-CR-3-CLS-OP1',
#   'LEFT-PS-3-CLS-OP1',
#   'RIGHT-PS-3-CLS-OP1'],
#  'RIGHT-CR-3-CTD-OP1': ['LEFT-CR-3-CTD-OP1',
#   'LEFT-PS-3-CTD-OP1',
#   'RIGHT-PS-3-CTD-OP1'],
#  'RIGHT-CR-4N-CLS-OP1': ['LEFT-CR-4N-CLS-OP1',
#   'LEFT-PS-4N-CLS-OP1',
#   'RIGHT-PS-4N-CLS-OP1'],
#  'RIGHT-CR-4N-CTD-OP1': ['LEFT-CR-4N-CTD-OP1',
#   'LEFT-PS-4N-CTD-OP1',
#   'RIGHT-PS-4N-CTD-OP1'],
#  'RIGHT-CR-4-CLS-OP1': ['LEFT-CR-4-CLS-OP1',
#   'LEFT-PS-4-CLS-OP1',
#   'RIGHT-PS-4-CLS-OP1'],
#  'RIGHT-CR-4-CTD-OP1': ['LEFT-CR-4-CTD-OP1',
#   'LEFT-PS-4-CTD-OP1',
#   'RIGHT-PS-4-CTD-OP1'],
#  'RIGHT-CR-5N-CLS-OP1': ['LEFT-CR-5N-CLS-OP1',
#   'LEFT-PS-5N-CLS-OP1',
#   'RIGHT-PS-5N-CLS-OP1'],
#  'RIGHT-CR-5N-CTD-OP1': ['LEFT-CR-5N-CTD-OP1',
#   'LEFT-PS-5N-CTD-OP1',
#   'RIGHT-PS-5N-CTD-OP1'],
#  'RIGHT-CR-5-CLS-OP1': ['LEFT-CR-5-CLS-OP1',
#   'LEFT-PS-5-CLS-OP1',
#   'RIGHT-PS-5-CLS-OP1'],
#  'RIGHT-CR-5-CTD-OP1': ['LEFT-CR-5-CTD-OP1',
#   'LEFT-PS-5-CTD-OP1',
#   'RIGHT-PS-5-CTD-OP1'],
#  'RIGHT-CR-6N-CLS-OP1': ['LEFT-CR-6N-CLS-OP1',
#   'LEFT-PS-6N-CLS-OP1',
#   'RIGHT-PS-6N-CLS-OP1'],
#  'RIGHT-CR-6N-CTD-OP1': ['LEFT-CR-6N-CTD-OP1',
#   'LEFT-PS-6N-CTD-OP1',
#   'RIGHT-PS-6N-CTD-OP1'],
#  'RIGHT-CR-6-CLS-OP1': ['LEFT-CR-6-CLS-OP1',
#   'LEFT-PS-6-CLS-OP1',
#   'RIGHT-PS-6-CLS-OP1'],
#  'RIGHT-CR-6-CTD-OP1': ['LEFT-CR-6-CTD-OP1',
#   'LEFT-PS-6-CTD-OP1',
#   'RIGHT-PS-6-CTD-OP1'],
#  'RIGHT-CR-7-CLS-OP1': ['LEFT-CR-7-CLS-OP1',
#   'LEFT-PS-7-CLS-OP1',
#   'RIGHT-PS-7-CLS-OP1'],
#  'RIGHT-CR-7-CTD-OP1': ['LEFT-CR-7-CTD-OP1',
#   'LEFT-PS-7-CTD-OP1',
#   'RIGHT-PS-7-CTD-OP1'],
#  'RIGHT-CR-8-CLS-OP1': ['LEFT-CR-8-CLS-OP1',
#   'LEFT-PS-8-CLS-OP1',
#   'RIGHT-PS-8-CLS-OP1'],
#  'RIGHT-CR-8-CTD-OP1': ['LEFT-CR-8-CTD-OP1',
#   'LEFT-PS-8-CTD-OP1',
#   'RIGHT-PS-8-CTD-OP1'],
#  'RIGHT-CR-9-CLS-OP1': ['LEFT-CR-9-CLS-OP1',
#   'LEFT-PS-9-CLS-OP1',
#   'RIGHT-PS-9-CLS-OP1'],
#  'RIGHT-CR-9-CTD-OP1': ['LEFT-CR-9-CTD-OP1',
#   'LEFT-PS-9-CTD-OP1',
#   'RIGHT-PS-9-CTD-OP1'],
#  'RIGHT-CR-10-CLS-OP1': ['LEFT-CR-10-CLS-OP1',
#   'LEFT-PS-10-CLS-OP1',
#   'RIGHT-PS-10-CLS-OP1'],
#  'RIGHT-CR-10-CTD-OP1': ['LEFT-CR-10-CTD-OP1',
#   'LEFT-PS-10-CTD-OP1',
#   'RIGHT-PS-10-CTD-OP1'],
#  'RIGHT-PS-1-CLS-OP1': ['LEFT-CR-1-CLS-OP1',
#   'LEFT-PS-1-CLS-OP1',
#   'RIGHT-CR-1-CLS-OP1'],
#  'RIGHT-PS-1-CTD-OP1': ['LEFT-CR-1-CTD-OP1',
#   'LEFT-PS-1-CTD-OP1',
#   'RIGHT-CR-1-CTD-OP1'],
#  'RIGHT-PS-2-CLS-OP1': ['LEFT-CR-2-CLS-OP1',
#   'LEFT-PS-2-CLS-OP1',
#   'RIGHT-CR-2-CLS-OP1'],
#  'RIGHT-PS-2-CTD-OP1': ['LEFT-CR-2-CTD-OP1',
#   'LEFT-PS-2-CTD-OP1',
#   'RIGHT-CR-2-CTD-OP1'],
#  'RIGHT-PS-3N-CLS-OP1': ['LEFT-CR-3N-CLS-OP1',
#   'LEFT-PS-3N-CLS-OP1',
#   'RIGHT-CR-3N-CLS-OP1'],
#  'RIGHT-PS-3N-CTD-OP1': ['LEFT-CR-3N-CTD-OP1',
#   'LEFT-PS-3N-CTD-OP1',
#   'RIGHT-CR-3N-CTD-OP1'],
#  'RIGHT-PS-3-CLS-OP1': ['LEFT-CR-3-CLS-OP1',
#   'LEFT-PS-3-CLS-OP1',
#   'RIGHT-CR-3-CLS-OP1'],
#  'RIGHT-PS-3-CTD-OP1': ['LEFT-CR-3-CTD-OP1',
#   'LEFT-PS-3-CTD-OP1',
#   'RIGHT-CR-3-CTD-OP1'],
#  'RIGHT-PS-4N-CLS-OP1': ['LEFT-CR-4N-CLS-OP1',
#   'LEFT-PS-4N-CLS-OP1',
#   'RIGHT-CR-4N-CLS-OP1'],
#  'RIGHT-PS-4N-CTD-OP1': ['LEFT-CR-4N-CTD-OP1',
#   'LEFT-PS-4N-CTD-OP1',
#   'RIGHT-CR-4N-CTD-OP1'],
#  'RIGHT-PS-4-CLS-OP1': ['LEFT-CR-4-CLS-OP1',
#   'LEFT-PS-4-CLS-OP1',
#   'RIGHT-CR-4-CLS-OP1'],
#  'RIGHT-PS-4-CTD-OP1': ['LEFT-CR-4-CTD-OP1',
#   'LEFT-PS-4-CTD-OP1',
#   'RIGHT-CR-4-CTD-OP1'],
#  'RIGHT-PS-5N-CLS-OP1': ['LEFT-CR-5N-CLS-OP1',
#   'LEFT-PS-5N-CLS-OP1',
#   'RIGHT-CR-5N-CLS-OP1'],
#  'RIGHT-PS-5N-CTD-OP1': ['LEFT-CR-5N-CTD-OP1',
#   'LEFT-PS-5N-CTD-OP1',
#   'RIGHT-CR-5N-CTD-OP1'],
#  'RIGHT-PS-5-CLS-OP1': ['LEFT-CR-5-CLS-OP1',
#   'LEFT-PS-5-CLS-OP1',
#   'RIGHT-CR-5-CLS-OP1'],
#  'RIGHT-PS-5-CTD-OP1': ['LEFT-CR-5-CTD-OP1',
#   'LEFT-PS-5-CTD-OP1',
#   'RIGHT-CR-5-CTD-OP1'],
#  'RIGHT-PS-6N-CLS-OP1': ['LEFT-CR-6N-CLS-OP1',
#   'LEFT-PS-6N-CLS-OP1',
#   'RIGHT-CR-6N-CLS-OP1'],
#  'RIGHT-PS-6N-CTD-OP1': ['LEFT-CR-6N-CTD-OP1',
#   'LEFT-PS-6N-CTD-OP1',
#   'RIGHT-CR-6N-CTD-OP1'],
#  'RIGHT-PS-6-CLS-OP1': ['LEFT-CR-6-CLS-OP1',
#   'LEFT-PS-6-CLS-OP1',
#   'RIGHT-CR-6-CLS-OP1'],
#  'RIGHT-PS-6-CTD-OP1': ['LEFT-CR-6-CTD-OP1',
#   'LEFT-PS-6-CTD-OP1',
#   'RIGHT-CR-6-CTD-OP1'],
#  'RIGHT-PS-7-CLS-OP1': ['LEFT-CR-7-CLS-OP1',
#   'LEFT-PS-7-CLS-OP1',
#   'RIGHT-CR-7-CLS-OP1'],
#  'RIGHT-PS-7-CTD-OP1': ['LEFT-CR-7-CTD-OP1',
#   'LEFT-PS-7-CTD-OP1',
#   'RIGHT-CR-7-CTD-OP1'],
#  'RIGHT-PS-8-CLS-OP1': ['LEFT-CR-8-CLS-OP1',
#   'LEFT-PS-8-CLS-OP1',
#   'RIGHT-CR-8-CLS-OP1'],
#  'RIGHT-PS-8-CTD-OP1': ['LEFT-CR-8-CTD-OP1',
#   'LEFT-PS-8-CTD-OP1',
#   'RIGHT-CR-8-CTD-OP1'],
#  'RIGHT-PS-9-CLS-OP1': ['LEFT-CR-9-CLS-OP1',
#   'LEFT-PS-9-CLS-OP1',
#   'RIGHT-CR-9-CLS-OP1'],
#  'RIGHT-PS-9-CTD-OP1': ['LEFT-CR-9-CTD-OP1',
#   'LEFT-PS-9-CTD-OP1',
#   'RIGHT-CR-9-CTD-OP1'],
#  'RIGHT-PS-10-CLS-OP1': ['LEFT-CR-10-CLS-OP1',
#   'LEFT-PS-10-CLS-OP1',
#   'RIGHT-CR-10-CLS-OP1'],
#  'RIGHT-PS-10-CTD-OP1': ['LEFT-CR-10-CTD-OP1',
#   'LEFT-PS-10-CTD-OP1',
#   'RIGHT-CR-10-CTD-OP1']}

# %%
# Save the compatibility dictionary for OP1 as a pickle file
with open('../data/05_model_input/compatibility_dict_op1.pkl', 'wb') as f:
    pickle.dump(compatibility_dict_op1, f)

print("Compatibility dictionary for OP1 saved as 'compatibility_dict_op1.pkl'.")
# Out:
# Compatibility dictionary for OP1 saved as 'compatibility_dict_op1.pkl'.

# %%
op1_list = list(compatibility_dict_op1.keys())

# %%
op1_list
# Out:
# ['LEFT-CR-1-CLS-OP1',
#  'LEFT-CR-1-CTD-OP1',
#  'LEFT-CR-2-CLS-OP1',
#  'LEFT-CR-2-CTD-OP1',
#  'LEFT-CR-3N-CLS-OP1',
#  'LEFT-CR-3N-CTD-OP1',
#  'LEFT-CR-3-CLS-OP1',
#  'LEFT-CR-3-CTD-OP1',
#  'LEFT-CR-4N-CLS-OP1',
#  'LEFT-CR-4N-CTD-OP1',
#  'LEFT-CR-4-CLS-OP1',
#  'LEFT-CR-4-CTD-OP1',
#  'LEFT-CR-5N-CLS-OP1',
#  'LEFT-CR-5N-CTD-OP1',
#  'LEFT-CR-5-CLS-OP1',
#  'LEFT-CR-5-CTD-OP1',
#  'LEFT-CR-6N-CLS-OP1',
#  'LEFT-CR-6N-CTD-OP1',
#  'LEFT-CR-6-CLS-OP1',
#  'LEFT-CR-6-CTD-OP1',
#  'LEFT-CR-7-CLS-OP1',
#  'LEFT-CR-7-CTD-OP1',
#  'LEFT-CR-8-CLS-OP1',
#  'LEFT-CR-8-CTD-OP1',
#  'LEFT-CR-9-CLS-OP1',
#  'LEFT-CR-9-CTD-OP1',
#  'LEFT-CR-10-CLS-OP1',
#  'LEFT-CR-10-CTD-OP1',
#  'LEFT-PS-1-CLS-OP1',
#  'LEFT-PS-1-CTD-OP1',
#  'LEFT-PS-2-CLS-OP1',
#  'LEFT-PS-2-CTD-OP1',
#  'LEFT-PS-3N-CLS-OP1',
#  'LEFT-PS-3N-CTD-OP1',
#  'LEFT-PS-3-CLS-OP1',
#  'LEFT-PS-3-CTD-OP1',
#  'LEFT-PS-4N-CLS-OP1',
#  'LEFT-PS-4N-CTD-OP1',
#  'LEFT-PS-4-CLS-OP1',
#  'LEFT-PS-4-CTD-OP1',
#  'LEFT-PS-5N-CLS-OP1',
#  'LEFT-PS-5N-CTD-OP1',
#  'LEFT-PS-5-CLS-OP1',
#  'LEFT-PS-5-CTD-OP1',
#  'LEFT-PS-6N-CLS-OP1',
#  'LEFT-PS-6N-CTD-OP1',
#  'LEFT-PS-6-CLS-OP1',
#  'LEFT-PS-6-CTD-OP1',
#  'LEFT-PS-7-CLS-OP1',
#  'LEFT-PS-7-CTD-OP1',
#  'LEFT-PS-8-CLS-OP1',
#  'LEFT-PS-8-CTD-OP1',
#  'LEFT-PS-9-CLS-OP1',
#  'LEFT-PS-9-CTD-OP1',
#  'LEFT-PS-10-CLS-OP1',
#  'LEFT-PS-10-CTD-OP1',
#  'RIGHT-CR-1-CLS-OP1',
#  'RIGHT-CR-1-CTD-OP1',
#  'RIGHT-CR-2-CLS-OP1',
#  'RIGHT-CR-2-CTD-OP1',
#  'RIGHT-CR-3N-CLS-OP1',
#  'RIGHT-CR-3N-CTD-OP1',
#  'RIGHT-CR-3-CLS-OP1',
#  'RIGHT-CR-3-CTD-OP1',
#  'RIGHT-CR-4N-CLS-OP1',
#  'RIGHT-CR-4N-CTD-OP1',
#  'RIGHT-CR-4-CLS-OP1',
#  'RIGHT-CR-4-CTD-OP1',
#  'RIGHT-CR-5N-CLS-OP1',
#  'RIGHT-CR-5N-CTD-OP1',
#  'RIGHT-CR-5-CLS-OP1',
#  'RIGHT-CR-5-CTD-OP1',
#  'RIGHT-CR-6N-CLS-OP1',
#  'RIGHT-CR-6N-CTD-OP1',
#  'RIGHT-CR-6-CLS-OP1',
#  'RIGHT-CR-6-CTD-OP1',
#  'RIGHT-CR-7-CLS-OP1',
#  'RIGHT-CR-7-CTD-OP1',
#  'RIGHT-CR-8-CLS-OP1',
#  'RIGHT-CR-8-CTD-OP1',
#  'RIGHT-CR-9-CLS-OP1',
#  'RIGHT-CR-9-CTD-OP1',
#  'RIGHT-CR-10-CLS-OP1',
#  'RIGHT-CR-10-CTD-OP1',
#  'RIGHT-PS-1-CLS-OP1',
#  'RIGHT-PS-1-CTD-OP1',
#  'RIGHT-PS-2-CLS-OP1',
#  'RIGHT-PS-2-CTD-OP1',
#  'RIGHT-PS-3N-CLS-OP1',
#  'RIGHT-PS-3N-CTD-OP1',
#  'RIGHT-PS-3-CLS-OP1',
#  'RIGHT-PS-3-CTD-OP1',
#  'RIGHT-PS-4N-CLS-OP1',
#  'RIGHT-PS-4N-CTD-OP1',
#  'RIGHT-PS-4-CLS-OP1',
#  'RIGHT-PS-4-CTD-OP1',
#  'RIGHT-PS-5N-CLS-OP1',
#  'RIGHT-PS-5N-CTD-OP1',
#  'RIGHT-PS-5-CLS-OP1',
#  'RIGHT-PS-5-CTD-OP1',
#  'RIGHT-PS-6N-CLS-OP1',
#  'RIGHT-PS-6N-CTD-OP1',
#  'RIGHT-PS-6-CLS-OP1',
#  'RIGHT-PS-6-CTD-OP1',
#  'RIGHT-PS-7-CLS-OP1',
#  'RIGHT-PS-7-CTD-OP1',
#  'RIGHT-PS-8-CLS-OP1',
#  'RIGHT-PS-8-CTD-OP1',
#  'RIGHT-PS-9-CLS-OP1',
#  'RIGHT-PS-9-CTD-OP1',
#  'RIGHT-PS-10-CLS-OP1',
#  'RIGHT-PS-10-CTD-OP1']

# %% [markdown]
# ## Create arbor dictionary

# %%
def generate_arbor_mapping(part_ids):
    # Cemented and Cementless Arbors Data from the Tables
    cemented_arbors = {
        '5': '1008644',
        '6': '1008654',
        '7': '1008663',
        '8': '1008668',
        '9': '1008672',
        '10': '1008677',
        '4N': '1008639',
        '5N': '1008649'
    }

    cementless_arbors = {
        '1': '800.6000.10.00',
        '2': '800.6001.11.00',
        '3': '800.6000.12.00',
        '4': '800.6000.13.00',
        '5': '800.6000.14.00',
        '6': '800.6000.15.00',
        '7': '800.6000.16.00',
        '8': '800.6000.17.00',
        '9': '800.6000.18.00',
        '10': '800.6000.19.00',
        '3N': '800.6000.20.00',
        '4N': '800.6001.13.00',
        '5N': '800.6001.14.00',
        '6N': '800.6000.23.00'
    }
    
    # Initialize the dictionary to store the results
    arbor_mapping = {}
    
    # Filter and process part IDs
    for part_id in part_ids:
        if part_id.endswith('OP1'):
            # Extract components
            orientation, type_id, size, cement_type, operation = part_id.split('-')
            
            # Normalize size for narrow cases
            size = size.replace(' (NARROW)', '')

            # Determine the correct arbor number based on cement type and size
            if cement_type == 'CTD':
                arbor_number = cemented_arbors.get(size)
            elif cement_type == 'CLS':
                arbor_number = cementless_arbors.get(size)
            else:
                arbor_number = None
            
            # Add to the dictionary
            if arbor_number:
                arbor_mapping[part_id] = arbor_number
    
    return arbor_mapping

# %%
arbor_dict = generate_arbor_mapping(op1_list)

# %%
arbor_dict
# Out:
# {'LEFT-CR-1-CLS-OP1': '800.6000.10.00',
#  'LEFT-CR-2-CLS-OP1': '800.6001.11.00',
#  'LEFT-CR-3N-CLS-OP1': '800.6000.20.00',
#  'LEFT-CR-3-CLS-OP1': '800.6000.12.00',
#  'LEFT-CR-4N-CLS-OP1': '800.6001.13.00',
#  'LEFT-CR-4N-CTD-OP1': '1008639',
#  'LEFT-CR-4-CLS-OP1': '800.6000.13.00',
#  'LEFT-CR-5N-CLS-OP1': '800.6001.14.00',
#  'LEFT-CR-5N-CTD-OP1': '1008649',
#  'LEFT-CR-5-CLS-OP1': '800.6000.14.00',
#  'LEFT-CR-5-CTD-OP1': '1008644',
#  'LEFT-CR-6N-CLS-OP1': '800.6000.23.00',
#  'LEFT-CR-6-CLS-OP1': '800.6000.15.00',
#  'LEFT-CR-6-CTD-OP1': '1008654',
#  'LEFT-CR-7-CLS-OP1': '800.6000.16.00',
#  'LEFT-CR-7-CTD-OP1': '1008663',
#  'LEFT-CR-8-CLS-OP1': '800.6000.17.00',
#  'LEFT-CR-8-CTD-OP1': '1008668',
#  'LEFT-CR-9-CLS-OP1': '800.6000.18.00',
#  'LEFT-CR-9-CTD-OP1': '1008672',
#  'LEFT-CR-10-CLS-OP1': '800.6000.19.00',
#  'LEFT-CR-10-CTD-OP1': '1008677',
#  'LEFT-PS-1-CLS-OP1': '800.6000.10.00',
#  'LEFT-PS-2-CLS-OP1': '800.6001.11.00',
#  'LEFT-PS-3N-CLS-OP1': '800.6000.20.00',
#  'LEFT-PS-3-CLS-OP1': '800.6000.12.00',
#  'LEFT-PS-4N-CLS-OP1': '800.6001.13.00',
#  'LEFT-PS-4N-CTD-OP1': '1008639',
#  'LEFT-PS-4-CLS-OP1': '800.6000.13.00',
#  'LEFT-PS-5N-CLS-OP1': '800.6001.14.00',
#  'LEFT-PS-5N-CTD-OP1': '1008649',
#  'LEFT-PS-5-CLS-OP1': '800.6000.14.00',
#  'LEFT-PS-5-CTD-OP1': '1008644',
#  'LEFT-PS-6N-CLS-OP1': '800.6000.23.00',
#  'LEFT-PS-6-CLS-OP1': '800.6000.15.00',
#  'LEFT-PS-6-CTD-OP1': '1008654',
#  'LEFT-PS-7-CLS-OP1': '800.6000.16.00',
#  'LEFT-PS-7-CTD-OP1': '1008663',
#  'LEFT-PS-8-CLS-OP1': '800.6000.17.00',
#  'LEFT-PS-8-CTD-OP1': '1008668',
#  'LEFT-PS-9-CLS-OP1': '800.6000.18.00',
#  'LEFT-PS-9-CTD-OP1': '1008672',
#  'LEFT-PS-10-CLS-OP1': '800.6000.19.00',
#  'LEFT-PS-10-CTD-OP1': '1008677',
#  'RIGHT-CR-1-CLS-OP1': '800.6000.10.00',
#  'RIGHT-CR-2-CLS-OP1': '800.6001.11.00',
#  'RIGHT-CR-3N-CLS-OP1': '800.6000.20.00',
#  'RIGHT-CR-3-CLS-OP1': '800.6000.12.00',
#  'RIGHT-CR-4N-CLS-OP1': '800.6001.13.00',
#  'RIGHT-CR-4N-CTD-OP1': '1008639',
#  'RIGHT-CR-4-CLS-OP1': '800.6000.13.00',
#  'RIGHT-CR-5N-CLS-OP1': '800.6001.14.00',
#  'RIGHT-CR-5N-CTD-OP1': '1008649',
#  'RIGHT-CR-5-CLS-OP1': '800.6000.14.00',
#  'RIGHT-CR-5-CTD-OP1': '1008644',
#  'RIGHT-CR-6N-CLS-OP1': '800.6000.23.00',
#  'RIGHT-CR-6-CLS-OP1': '800.6000.15.00',
#  'RIGHT-CR-6-CTD-OP1': '1008654',
#  'RIGHT-CR-7-CLS-OP1': '800.6000.16.00',
#  'RIGHT-CR-7-CTD-OP1': '1008663',
#  'RIGHT-CR-8-CLS-OP1': '800.6000.17.00',
#  'RIGHT-CR-8-CTD-OP1': '1008668',
#  'RIGHT-CR-9-CLS-OP1': '800.6000.18.00',
#  'RIGHT-CR-9-CTD-OP1': '1008672',
#  'RIGHT-CR-10-CLS-OP1': '800.6000.19.00',
#  'RIGHT-CR-10-CTD-OP1': '1008677',
#  'RIGHT-PS-1-CLS-OP1': '800.6000.10.00',
#  'RIGHT-PS-2-CLS-OP1': '800.6001.11.00',
#  'RIGHT-PS-3N-CLS-OP1': '800.6000.20.00',
#  'RIGHT-PS-3-CLS-OP1': '800.6000.12.00',
#  'RIGHT-PS-4N-CLS-OP1': '800.6001.13.00',
#  'RIGHT-PS-4N-CTD-OP1': '1008639',
#  'RIGHT-PS-4-CLS-OP1': '800.6000.13.00',
#  'RIGHT-PS-5N-CLS-OP1': '800.6001.14.00',
#  'RIGHT-PS-5N-CTD-OP1': '1008649',
#  'RIGHT-PS-5-CLS-OP1': '800.6000.14.00',
#  'RIGHT-PS-5-CTD-OP1': '1008644',
#  'RIGHT-PS-6N-CLS-OP1': '800.6000.23.00',
#  'RIGHT-PS-6-CLS-OP1': '800.6000.15.00',
#  'RIGHT-PS-6-CTD-OP1': '1008654',
#  'RIGHT-PS-7-CLS-OP1': '800.6000.16.00',
#  'RIGHT-PS-7-CTD-OP1': '1008663',
#  'RIGHT-PS-8-CLS-OP1': '800.6000.17.00',
#  'RIGHT-PS-8-CTD-OP1': '1008668',
#  'RIGHT-PS-9-CLS-OP1': '800.6000.18.00',
#  'RIGHT-PS-9-CTD-OP1': '1008672',
#  'RIGHT-PS-10-CLS-OP1': '800.6000.19.00',
#  'RIGHT-PS-10-CTD-OP1': '1008677'}
