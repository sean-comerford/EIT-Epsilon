# %%
import pandas as pd
import numpy as np
import random
from statistics import mean
import matplotlib.pyplot as plt
import copy

# %% [markdown]
# # Notes
# 1. Schedule entry structure is (grid electricity used, pv used, battery change, state of battery charge (soc), hour index)
# 2. Battery change is positive when charging and negative when discharging.
# 3. Fitness is cost, so lower cost (i.e. lower fitness) is better.
# 4. To set battery capacity and battery charge/discharge rate to 0, do not set to exactly 0 as this will result in errors when creating different offspring (see OneNote notes). Instead, set to a very small number such as 0.001.
# 5. Schedules with a lower fitness get a higher mutation rate to explore the solution space, while schedules with a higher fitness get a lower mutation rate so that they are not disrupted by mutation.
# 6. When graphing the battery change, each battery change value is multiplied by -1. This is to be consistant in the graph with the energy drawn from the grid and pv system (both positive). So by multiplying the battery change by -1, the energy drawn from the battery system is also positive.

# %% [markdown]
# # Parameters

# %%
start_date = '2022-06-03 00:00:00'
end_date = '2022-06-08 00:00:00'
max_iterations = 20
n_c = 0.2
n_e = 0.1
pop_size = 1000 # Have to have a high population size for crossover function to work properly
battery_cap = 200  # in kWh
battery_charge_discharge_rate = 100  # in kW
initial_soc = 0 # in kWh, the state of charge in the battery at the start of the time horizon
charge_discharge_percentage = random.uniform(0.5, 1)

# %% [markdown]
# # Data Preprocessing

# %%
df_prediction = pd.read_csv('Vyskov.csv')
df_consumption = pd.read_csv('historie-spotreb-elektrina.csv')
column_renames = {"Datum a čas": "Timestamp",
                  "Činná spotřeba hodinová (kWh)": "Hourly consumption (kWh)",
                  "Jalová spotřeba při spotřebě hodinová (kVAR)": "Reactive hourly consumption (kVAR)",
                  "Jalová dodávka při spotřebě hodinová (kVAR)": "Reactive supply hourly consumption (kVAR)"
                  }
df_consumption = df_consumption.rename(columns=column_renames)

prediction_column_rename = {"time_utc": "Timestamp", "production_prediction": "PV Energy Prediction (kWh)"}

df_prediction = df_prediction.rename(columns = prediction_column_rename)

df_consumption['Timestamp'] = pd.to_datetime(df_consumption['Timestamp'], format='%d.%m.%Y %H:%M')
df_prediction['Timestamp'] = pd.to_datetime(df_prediction['Timestamp'], format='%d/%m/%Y %H:%M')

# %%
df_consumption = df_consumption[["Timestamp", "Hourly consumption (kWh)"]]
df_prediction = df_prediction[["Timestamp", "PV Energy Prediction (kWh)"]]


df_combined = pd.merge(df_consumption, df_prediction, on="Timestamp")
df_combined.set_index('Timestamp', inplace=True)

# %%
# Define TOU rates for 24 hours (hour 0 = 0.23, hour 1 = 0.28, etc.)
tou_rates = {
    0: 0.23, 1: 0.28, 2: 0.27, 3: 0.25, 4: 0.22, 5: 0.20,   # 12 AM - 6 AM
    6: 0.30, 7: 0.35, 8: 0.40, 9: 0.45, 10: 0.42, 11: 0.38, # 6 AM - 12 PM
    12: 0.46, 13: 0.44, 14: 0.52, 15: 0.53, 16: 0.47, 17: 0.68, # 12 PM - 6 PM
    18: 0.64, 19: 0.50, 20: 0.45, 21: 0.35, 22: 0.29, 23: 0.22  # 6 PM - 12 AM
}

# %%
# Function to slice the DataFrame based on the start and end date
def get_time_horizon(df, start_date, end_date):
    # Ensure start_date and end_date are datetime objects
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)
    
    # Slice the DataFrame using the loc function
    sliced_df = df.loc[start_date:end_date].copy()
    
    return sliced_df

# Get the sliced DataFrame for the defined time horizon
df = get_time_horizon(df_combined, start_date, end_date)

# Extract the hour and assign TOU rates using .loc to avoid the SettingWithCopyWarning
df.loc[:, 'hour'] = df.index.hour
df.loc[:, 'TOU (€/kWh)'] = df['hour'].map(tou_rates)

# Drop the 'hour' column as it's no longer needed
df.drop(columns=['hour'], inplace=True)

df.head(60)
# Out:
#                      Hourly consumption (kWh)  PV Energy Prediction (kWh)  \
# Timestamp
# 2022-06-03 00:00:00                        98                    0.000607
# 2022-06-03 01:00:00                        78                    0.000607
# 2022-06-03 02:00:00                        81                    0.000607
# 2022-06-03 03:00:00                        87                    0.000607
# 2022-06-03 04:00:00                        52                    0.399600
# 2022-06-03 05:00:00                        91                    6.550200
# 2022-06-03 06:00:00                       177                   15.530400
# 2022-06-03 07:00:00                       208                   17.878418
# 2022-06-03 08:00:00                       350                   35.947800
# 2022-06-03 09:00:00                       261                   53.586900
# 2022-06-03 10:00:00                       342                   52.199100
# 2022-06-03 11:00:00                       366                   61.766031
# 2022-06-03 12:00:00                       269                   64.776352
# 2022-06-03 13:00:00                       169                   71.916211
# 2022-06-03 14:00:00                       253                   60.442904
# 2022-06-03 15:00:00                       310                   52.666791
# 2022-06-03 16:00:00                       409                   41.662080
# 2022-06-03 17:00:00                       360                   25.499375
# 2022-06-03 18:00:00                       301                   11.459465
# 2022-06-03 19:00:00                       323                    1.825200
# 2022-06-03 20:00:00                       250                    0.000607
# 2022-06-03 21:00:00                       238                    0.000607
# 2022-06-03 22:00:00                       215                    0.000607
# 2022-06-03 23:00:00                       176                    0.000607
# 2022-06-04 00:00:00                       149                    0.000607
# 2022-06-04 01:00:00                       114                    0.000607
# 2022-06-04 02:00:00                       119                    0.000607
# 2022-06-04 03:00:00                        95                    0.000607
# 2022-06-04 04:00:00                        70                    0.408155
# 2022-06-04 05:00:00                       161                    1.274400
# 2022-06-04 06:00:00                       249                    4.558950
# 2022-06-04 07:00:00                       302                   27.898200
# 2022-06-04 08:00:00                       245                   35.645400
# 2022-06-04 09:00:00                       319                   53.247240
# 2022-06-04 10:00:00                       299                   62.055124
# 2022-06-04 11:00:00                       324                   66.490108
# 2022-06-04 12:00:00                       203                   64.776352
# 2022-06-04 13:00:00                       259                   53.961545
# 2022-06-04 14:00:00                       242                   37.417876
# 2022-06-04 15:00:00                       193                   42.926564
# 2022-06-04 16:00:00                       215                   25.499375
# 2022-06-04 17:00:00                       178                   16.567872
# 2022-06-04 18:00:00                       144                    7.728483
# 2022-06-04 19:00:00                       141                    2.462400
# 2022-06-04 20:00:00                        95                    0.000607
# 2022-06-04 21:00:00                       121                    0.000607
# 2022-06-04 22:00:00                       136                    0.000607
# 2022-06-04 23:00:00                       102                    0.000607
# 2022-06-05 00:00:00                        93                    0.000607
# 2022-06-05 01:00:00                        88                    0.000607
# 2022-06-05 02:00:00                        79                    0.000607
# 2022-06-05 03:00:00                        79                    0.000607
# 2022-06-05 04:00:00                        67                    0.550800
# 2022-06-05 05:00:00                        49                    3.674700
# 2022-06-05 06:00:00                        98                   13.894200
# 2022-06-05 07:00:00                       213                   31.579200
# 2022-06-05 08:00:00                       210                   53.961545
# 2022-06-05 09:00:00                       145                   46.164600
# 2022-06-05 10:00:00                       104                   62.762580
# 2022-06-05 11:00:00                       132                   71.916211
#
#                      TOU (€/kWh)
# Timestamp
# 2022-06-03 00:00:00         0.23
# 2022-06-03 01:00:00         0.28
# 2022-06-03 02:00:00         0.27
# 2022-06-03 03:00:00         0.25
# 2022-06-03 04:00:00         0.22
# 2022-06-03 05:00:00         0.20
# 2022-06-03 06:00:00         0.30
# 2022-06-03 07:00:00         0.35
# 2022-06-03 08:00:00         0.40
# 2022-06-03 09:00:00         0.45
# 2022-06-03 10:00:00         0.42
# 2022-06-03 11:00:00         0.38
# 2022-06-03 12:00:00         0.46
# 2022-06-03 13:00:00         0.44
# 2022-06-03 14:00:00         0.52
# 2022-06-03 15:00:00         0.53
# 2022-06-03 16:00:00         0.47
# 2022-06-03 17:00:00         0.68
# 2022-06-03 18:00:00         0.64
# 2022-06-03 19:00:00         0.50
# 2022-06-03 20:00:00         0.45
# 2022-06-03 21:00:00         0.35
# 2022-06-03 22:00:00         0.29
# 2022-06-03 23:00:00         0.22
# 2022-06-04 00:00:00         0.23
# 2022-06-04 01:00:00         0.28
# 2022-06-04 02:00:00         0.27
# 2022-06-04 03:00:00         0.25
# 2022-06-04 04:00:00         0.22
# 2022-06-04 05:00:00         0.20
# 2022-06-04 06:00:00         0.30
# 2022-06-04 07:00:00         0.35
# 2022-06-04 08:00:00         0.40
# 2022-06-04 09:00:00         0.45
# 2022-06-04 10:00:00         0.42
# 2022-06-04 11:00:00         0.38
# 2022-06-04 12:00:00         0.46
# 2022-06-04 13:00:00         0.44
# 2022-06-04 14:00:00         0.52
# 2022-06-04 15:00:00         0.53
# 2022-06-04 16:00:00         0.47
# 2022-06-04 17:00:00         0.68
# 2022-06-04 18:00:00         0.64
# 2022-06-04 19:00:00         0.50
# 2022-06-04 20:00:00         0.45
# 2022-06-04 21:00:00         0.35
# 2022-06-04 22:00:00         0.29
# 2022-06-04 23:00:00         0.22
# 2022-06-05 00:00:00         0.23
# 2022-06-05 01:00:00         0.28
# 2022-06-05 02:00:00         0.27
# 2022-06-05 03:00:00         0.25
# 2022-06-05 04:00:00         0.22
# 2022-06-05 05:00:00         0.20
# 2022-06-05 06:00:00         0.30
# 2022-06-05 07:00:00         0.35
# 2022-06-05 08:00:00         0.40
# 2022-06-05 09:00:00         0.45
# 2022-06-05 10:00:00         0.42
# 2022-06-05 11:00:00         0.38

# %% [markdown]
# # GA functions

# %%
# Function to initialise a single schedule
def init_schedule(df):
    schedule = []
    soc = initial_soc  # Initial state of charge of the battery
    
    for t in range(len(df)):
        timestamp = df.index[t]
        hourly_consumption = df['Hourly consumption (kWh)'][t]
        pv_available = df['PV Energy Prediction (kWh)'][t]
        tou_rate = df['TOU (€/kWh)'][t]
        
        # Generate a random floats
        random_roll = random.random()
        
        # If the TOU is low, store the majority of the pv energy and use only some of it now, with a high probability.
        # Update soc with this pv energy that has gone into the battery.
        if tou_rate < 0.6 and random_roll < 0.9:
            pv_charge_percentage = random.uniform(0.7, 1)
        else:
            # If the TOU is high, use majority of the PV now and store only some of it.
            pv_charge_percentage = random.uniform(0, 0.3)
            
        
        # Determine the pv energy charge amount (kWh)
        pv_charge_amount = pv_available * pv_charge_percentage


        # The PV charge amount battery is restricted by the charge/discharge rate and the remaining capacity in the battery
        pv_into_battery = min(battery_charge_discharge_rate, battery_cap - soc, pv_charge_amount)


        # Remainig pv energy to use now
        pv_use_now = min(hourly_consumption, (pv_available - pv_into_battery))
            
        
        if pv_into_battery == pv_charge_amount:
            # This means that there is more room for charging the battery as pv_into_battery < battery_charge_discharge_rate and remaining capacity in battery
            battery_charging_potential = min(battery_charge_discharge_rate, battery_cap - soc) - pv_charge_amount
        else:
            battery_charging_potential = 0
            
        # Use this remaining battery charging potential with grid energy during low TOU
        if tou_rate < 0.6 and random_roll < 0.9:
            
            # battery_change_not_pv is the change in the battery charge for this timestep not including the pv into the battery
            battery_change_not_pv = battery_charging_potential * charge_discharge_percentage
            battery_change = battery_change_not_pv + pv_into_battery
        else:
            # During high TOU, discharge the battery
            # Determine the discharge rate. Either the maximum discharge rate or whatever is left in the battery or whatever the hourly consumption is less what has been used by PV
            discharge_rate = max(-battery_charge_discharge_rate, -soc, -hourly_consumption + pv_use_now)

            battery_change_not_pv = charge_discharge_percentage * discharge_rate
            battery_change = battery_change_not_pv + pv_into_battery

        # Update SOC
        soc += battery_change

        # Ensure SOC stays within limits
        #soc = max(0, min(battery_cap, soc))
        if soc < 0 or soc > battery_cap:
            print(f"ERROR: SOC OUT OF BOUNDS")

        # Determine grid usage
        grid_usage = max(0, hourly_consumption - pv_use_now + battery_change)

        # Append the tuple (grid_usage, pv_used, battery_change, soc, hour) to the schedule
        schedule.append((grid_usage, pv_use_now, battery_change, soc, t, pv_into_battery, battery_change_not_pv))
        
        if abs(pv_available - pv_into_battery - pv_use_now) > 1e-3:
            print(f"ERROR: PV AVAILABLE NOT EQUAL TO PV INTO BATTERY AND PV USED NOW")
            print(f"SOC = {soc}, PV available = {pv_available}, PV into battery = {pv_into_battery}, pv use now = {pv_use_now}")
            
        # Debugging
        if t == 0:
            previous_soc = initial_soc
        else:
            previous_soc = schedule[t-1][3]
        
        if previous_soc + battery_change != soc:
            print(f"ERROR IN INITIALISATION FUNCTION, PREVIOUS SOC + BATTERY CHANGE != CURRENT SOC")
            print(f" Hour = {t}, Previous SOC = {previous_soc:.3f}, Battery Change = {battery_change:.3f}, Current SOC = {soc:.3f}")
        
        #print(f"TOU = {tou_rate}, Hour = {t}, Total Battery Change = {battery_change:.3f}, Battery change from PV = {pv_into_battery:.3f}, Battery change not PV = {battery_change_not_pv:.3f}")
        
        
        if abs(hourly_consumption - (grid_usage + pv_use_now - battery_change)) > 1e-3:
            print("ERROR IN INITIALISATION FUNCTION, ENERGY IMBALANCE")
            print(f"Hour = {t}, tou rate = {tou_rate}, hourly consumption = {hourly_consumption}, Grid usage = {grid_usage}, PV used = {pv_use_now}, battery change = {battery_change}")
        #print(f"Hour = {t}, Grid Usage = {grid_usage:.2f} kWh, PV used = {pv_used:.2f} kWh, Battery Change = {battery_change:.2f}, SOC = {soc:.2f}")
        
        if battery_change > battery_charge_discharge_rate:
            print(f"Error in initialisation function, battery change invalid")

    return schedule

# %%
# Function to initialise the population
def init_population(df, pop_size):
    population = [init_schedule(df) for _ in range(pop_size)]
    return population

# %%
# Fitness function to evaluate a schedule
def schedule_fitness(schedule, df):
    tou_rates = df['TOU (€/kWh)'].values
    total_cost = 0
    for (grid_usage, pv_used, battery_change, soc, hour, pv_into_battery, battery_change_not_pv) in schedule:
        total_cost += grid_usage * tou_rates[hour]
    return total_cost

# %%
# Example usage with a population and corresponding TOU rates
def evaluate_population(population, df):
    tou_rates = df['TOU (€/kWh)'].values
    fitness_values = []
    for individual in population:
        fitness_values.append(schedule_fitness(individual, df))
    average_fitness = mean(fitness_values)
    return fitness_values, average_fitness

# %%
# Selection function to select the top n individuals
def select_top_n(population, df, n):
    fitnesses, _ = evaluate_population(population, df)
    # Sorts the population indices in ascending order according to fitness
    sorted_indices = np.argsort(fitnesses)
    
    # Select the top n individuals
    best_schedules = [population[i] for i in sorted_indices[:n]]
    
    return best_schedules

# %%
def resolve_conflict(offspring, df):
    schedule_counter = 0
    for idx, schedule in enumerate(offspring):
        schedule_counter += 1
        #print(f"Schedule = {schedule_counter}")
        for i in range(len(schedule)):
            grid_usage, pv_use_now, current_battery_change, current_soc, hour_idx, pv_into_battery, battery_change_not_pv = schedule[i]

            if i == 0:
                previous_soc = initial_soc
            else:
                previous_soc = schedule[i-1][3]

            # Update the soc after crossover and mutation
            new_soc = previous_soc + current_battery_change
            schedule[i] = (grid_usage, pv_use_now, current_battery_change, new_soc, hour_idx, pv_into_battery, battery_change_not_pv)
            
            #print(f"Hour before update = {hour_idx}")

            # Check if SOC is out of bounds
            if new_soc < 0 or new_soc > battery_cap:
                new_soc = previous_soc  # Reset SOC to previous valid SOC

                # Fetch data for this hour
                hourly_consumption = df['Hourly consumption (kWh)'][hour_idx]
                pv_available = df['PV Energy Prediction (kWh)'][hour_idx]
                tou_rate = df['TOU (€/kWh)'][hour_idx]

                # Generate random float to decide mutation behavior
                random_roll = random.random()

                # Adjust battery charge behavior based on TOU rate
                if tou_rate < 0.6 and random_roll < 0.9:
                    pv_charge_percentage = random.uniform(0.7, 1)
                else:
                    pv_charge_percentage = random.uniform(0, 0.3)

                # Calculate PV charge amount and energy into the battery
                pv_charge_amount = pv_available * pv_charge_percentage
                pv_into_battery = min(battery_charge_discharge_rate, battery_cap - new_soc, pv_charge_amount)

                # Use remaining PV energy for immediate consumption
                pv_use_now = min(hourly_consumption, (pv_available - pv_into_battery))

                # Calculate remaining charging potential if needed
                battery_charging_potential = max(0, min((battery_cap - new_soc - pv_into_battery), battery_charge_discharge_rate - pv_into_battery))

                # Update battery charge or discharge
                if tou_rate < 0.6 and random_roll < 0.9:
                    battery_change_not_pv = battery_charging_potential * charge_discharge_percentage
                    battery_change = battery_change_not_pv + pv_into_battery
                else:
                    discharge_rate = max(-battery_charge_discharge_rate, -new_soc, -hourly_consumption + pv_use_now)
                    battery_change_not_pv = charge_discharge_percentage * discharge_rate
                    battery_change = battery_change_not_pv + pv_into_battery

                # Update new SOC after adjustment
                new_soc = previous_soc + battery_change

                # Ensure SOC is within bounds after adjustment
                #new_soc = max(0, min(new_soc, battery_cap))

                # Calculate grid usage based on remaining hourly consumption
                grid_usage = max(0, hourly_consumption - pv_use_now + battery_change)

                # Now update the schedule in place by reassigning the tuple
                schedule[i] = (grid_usage, pv_use_now, battery_change, new_soc, hour_idx, pv_into_battery, battery_change_not_pv)
                if battery_change > battery_charge_discharge_rate:
                    print(f"ERROR IN RESOLVE CONFLICT, BATTERY CHANGE Invalid")
                    #print(f"Battery charging potential = {battery_charging_potential}")
                    print(f"HOUR = {hour_idx}, Battery change = {battery_change}, battery change not pv = {battery_change_not_pv}, pv into battery = {pv_into_battery}")
                
                if new_soc > battery_cap or new_soc < 0:
                    print(f"Resolved new soc is still invalid = {new_soc:.3f}, previous soc = {previous_soc:.3f}, Battery change not pv = {battery_change_not_pv:.3f}, pv into battery = {pv_into_battery:.3f}")

            
            # If the current soc changes, update all subsequent SOC values
            
            if current_soc != new_soc:
                #print(f"Updating all susequent soc values after hour {hour_idx}")
                #print(f"New soc = {new_soc}")
                for t in range(hour_idx + 1, len(schedule)):
                    #print(f"Updating all subsequent soc values")
                    grid, pv_use_now, battery_change, soc, hour_index, pv_into_battery, battery_change_not_pv = schedule[t]
                    previous_soc = schedule[t-1][3]
                    #print(f"Hour = {t}, previous soc = {previous_soc}, current battery change = {battery_change}")
                    updated_new_soc = previous_soc + battery_change
                    #updated_new_soc = max(0, min(updated_new_soc, battery_cap))  # Ensure bounds

                    # Now update the tuple in the schedule in place
                    schedule[t] = (grid, pv_use_now, battery_change, updated_new_soc, hour_index, pv_into_battery, battery_change_not_pv)

                    if battery_change > battery_charge_discharge_rate:
                        print(f"ERROR IN RESOLVE CONFLICT AFTER UPDATE, BATTERY CHANGE TOO HIGH")
                        print(f"Hour = {t}, Battery change = {battery_change}, battery change not pv = {battery_change_not_pv}, pv into battery = {pv_into_battery}")



    return offspring

# %%
def crossover(population, best_solutions, n_c, n_e, num_points=2):
    
    offspring = copy.deepcopy(best_solutions)
    # Number of child solutions to generate from best_solutions
    iter_count = len(population) * (n_c + n_e)
    max_attempts = 5
    
    
    while len(offspring) < iter_count:
        parent1, parent2 = random.sample(best_solutions, 2)
        attempts = 0
        # print(f"Length of best solutions = {len(best_solutions)}")
        while parent1 == parent2 and attempts < max_attempts:
            print(f"ERROR: BOTH PARENTS EQUAL, PICKING NEW PARENT (Attempt {attempts + 1})")
            parent2 = random.choice(best_solutions)
            attempts += 1
        
        
        # Generate unique crossover points
        crossover_points = sorted(np.random.choice(range(1, len(parent1) - 1), num_points, replace=False))
        crossover_points = [0] + crossover_points + [len(parent1)]  # Add start and end points
        #print(f"Crossover points are {crossover_points}")
    
        offspring1, offspring2 = [], []

        for i in range(len(crossover_points) - 1):
            start, end = crossover_points[i], crossover_points[i + 1]
            if i % 2 == 0:
                offspring1.extend(parent1[start:end])
                offspring2.extend(parent2[start:end])
            else:
                offspring1.extend(parent2[start:end])
                offspring2.extend(parent1[start:end])
        

       
        # Attempting to add two offspring to the list of best solutions
        if offspring1 not in offspring:
            offspring.append(offspring1)
            #print(f"Offspring 1 is not in best_solutions")
        #else:
            #print(f"ERROR: Offspring 1 is in best_solutions")

        if offspring2 not in offspring:
            offspring.append(offspring2)
            #print(f"Offspring 2 is not in best_solutions")
        #else:
            #print(f"ERROR: Offspring 2 is in best_solutions")
        
        
        
    for schedule in offspring:
        for i in range(len(schedule)):
            grid_usage, pv_use_now, battery_change, soc, hour, pv_into_battery, battery_change_not_pv = schedule[i]
            if battery_change > battery_charge_discharge_rate:
                print(f"Battery change is too high after offspring {battery_change}")
    return offspring

# %%
def mutation(population):
    _, average_fitness = evaluate_population(population, df)
    #print(f"Average fitness = {average_fitness:.2f}")
    # For debugging
    schedule_number = 0
    num_low_fit, num_good_fit = 0, 0
    mutated_battery_change = None
    
    # debugging
    pop_before_mutation = population
    
    for schedule in population:
        
        schedule_number += 1
        '''
        schedule_before_mutation = schedule
        schedule_fitness_before_mutation = schedule_fitness(schedule_before_mutation, df)
        print(f"Schedule {schedule_number} fitness before mutation = {schedule_fitness_before_mutation}")
        '''
        
        fitness = schedule_fitness(schedule, df)
        if fitness < average_fitness:
            schedule_mutation_rate = 0.2
            entry_mutation_rate = 0.15
        else:
            schedule_mutation_rate = 0.25
            entry_mutation_rate = 0.2
        
        random_roll_1 = random.random()
        
        if random_roll_1 <= schedule_mutation_rate:
            for i in range(len(schedule)):
                if i == 0:
                    previous_soc = initial_soc
                else:
                    previous_soc = schedule[i-1][3]
                grid_usage, pv_use_now, battery_change, soc, hour, pv_into_battery, battery_change_not_pv = schedule[i]
                hourly_consumption = df['Hourly consumption (kWh)'][i]

                if previous_soc + battery_change != soc:
                    #print(f"Error before mutation function, previous soc + battery change != soc")
                    #print(f"Previous Soc = {previous_soc}, battery change = {battery_change}, soc = {soc}")
                    updated_soc = previous_soc + battery_change
                else:
                    updated_soc = soc
                schedule[i] = grid_usage, pv_use_now, battery_change, updated_soc, hour, pv_into_battery, battery_change_not_pv
                
                
                if updated_soc < 0 or updated_soc > battery_cap:
                    updated_soc = previous_soc
                    # Must update the battery usage
                    
                    # Fetch data for this hour
                    hourly_consumption = df['Hourly consumption (kWh)'][hour]
                    pv_available = df['PV Energy Prediction (kWh)'][hour]
                    tou_rate = df['TOU (€/kWh)'][hour]

                    # Generate random float to decide mutation behavior
                    random_roll = random.random()

                    # Adjust battery charge behavior based on TOU rate
                    if tou_rate < 0.6 and random_roll < 0.9:
                        pv_charge_percentage = random.uniform(0.7, 1)
                    else:
                        pv_charge_percentage = random.uniform(0, 0.3)

                    # Calculate PV charge amount and energy into the battery
                    pv_charge_amount = pv_available * pv_charge_percentage
                    pv_into_battery = min(battery_charge_discharge_rate, battery_cap - updated_soc, pv_charge_amount)

                    # Use remaining PV energy for immediate consumption
                    pv_use_now = min(hourly_consumption, (pv_available - pv_into_battery))

                    # Calculate remaining charging potential if needed
                    battery_charging_potential = max(0, min((battery_cap - updated_soc - pv_into_battery), battery_charge_discharge_rate - pv_into_battery))

                    # Update battery charge or discharge
                    if tou_rate < 0.6 and random_roll < 0.9:
                        battery_change_not_pv = battery_charging_potential * charge_discharge_percentage
                        battery_change = battery_change_not_pv + pv_into_battery
                    else:
                        discharge_rate = max(-battery_charge_discharge_rate, -updated_soc, -hourly_consumption + pv_use_now)
                        battery_change_not_pv = charge_discharge_percentage * discharge_rate
                        battery_change = battery_change_not_pv + pv_into_battery

                    # Update new SOC after adjustment
                    updated_soc = previous_soc + battery_change

                    # Ensure SOC is within bounds after adjustment
                    #new_soc = max(0, min(new_soc, battery_cap))

                    # Calculate grid usage based on remaining hourly consumption
                    grid_usage = max(0, hourly_consumption - pv_use_now + battery_change)

                    # Now update the schedule in place by reassigning the tuple
                    schedule[i] = (grid_usage, pv_use_now, battery_change, updated_soc, hour, pv_into_battery, battery_change_not_pv)
        
        
                random_roll_2 = random.random()
                
                if random_roll_2 <= entry_mutation_rate:
                    #print(f"Mutation is taking place for schedule {schedule_number}")
                    mutation_percentage = random.uniform(-0.5, 0.5)
                    mutation_amount = battery_change_not_pv * mutation_percentage
                    mutated_battery_change_not_pv = battery_change_not_pv + mutation_amount
                    mutated_battery_change = pv_into_battery + mutated_battery_change_not_pv
                    
                    mutated_soc = previous_soc + mutated_battery_change
                    charge_amount = 0

                    
                    if mutated_battery_change > 0 and (mutated_battery_change > battery_charge_discharge_rate or (mutated_battery_change + previous_soc) > battery_cap) :
                        #print(f"Invalid mutated battery charge = {mutated_battery_change}")
                        # How much room is left to charge the battery
                        charge_potential = max(0, (min(battery_charge_discharge_rate - pv_into_battery, battery_cap - previous_soc - pv_into_battery)))
                        #print(f"PV into battery = {pv_into_battery}, Soc = {soc}, charge potential = {charge_potential}")
                        
                        charge_percentage = random.uniform(0, 1)
                        mutated_battery_change_not_pv = charge_potential * charge_percentage
                        
                        # Update mutated_battery_change
                        mutated_battery_change = mutated_battery_change_not_pv + pv_into_battery
                        
                        
                        # Update mutated_soc
                        mutated_soc = previous_soc + mutated_battery_change
                        if mutated_soc < 0 or mutated_soc > battery_cap:
                            print(f"Still invalid mutated soc after adjusting battery charge. Mutated soc = {mutated_soc}")
                        
                        
                    
                    if mutated_battery_change < 0 and (mutated_battery_change < -battery_charge_discharge_rate or (mutated_battery_change + previous_soc) < 0):
                        #print(f"Invalid mutated battery discharge = {mutated_battery_change}")
                        # How much room is left for the battery to discharge
                        discharge_potential = max(-battery_charge_discharge_rate, -updated_soc)
                        
                        discharge_percentage = random.uniform(0, 1)
                        mutated_battery_change_not_pv = discharge_potential * discharge_percentage
                        
                        mutated_battery_change = mutated_battery_change_not_pv + pv_into_battery
                        
                        mutated_soc = previous_soc + mutated_battery_change
                        if mutated_soc < 0 or mutated_soc > battery_cap:
                            print(f"Still invalid soc after adjusting battery discharge")
                            print(f"Invalid soc = {mutated_soc}")
                        
                    '''
                    if mutated_soc < 0 or mutated_soc > battery_cap:
                        print(f"Invalid mutated soc = {mutated_soc}")
                        print(f"Previous soc = {previous_soc}, Charge Amount = {charge_amount}, Mutated battery change = {mutated_battery_change}")
                    '''
                    #print(f"Original soc = {soc}, Mutated SOC = {mutated_soc}")    
                    grid_usage = max(0, hourly_consumption - pv_use_now + mutated_battery_change)
                    schedule[i] = (grid_usage, pv_use_now, mutated_battery_change, mutated_soc, hour, pv_into_battery, mutated_battery_change_not_pv)
                    if mutated_battery_change > battery_charge_discharge_rate:
                        print(f"ERROR IN MUTATATION FUNCTION, BATTERY CHANGE INVALID")

        '''
        # Debugging
        mutated_schedule = schedule
        mutated_schedule_fitness = schedule_fitness(mutated_schedule, df)
        print(f"Mutated Schedule {schedule_number} fitness = {mutated_schedule_fitness}")
        '''        

    
        for i in range(len(schedule)):
            grid_usage, pv_use_now, battery_change, soc, hour, pv_into_battery, battery_change_not_pv = schedule[i]
        
            if battery_change > battery_charge_discharge_rate:
                print(f"When returning pop from mutation, found that battery change is invalid = {battery_change} for hour {i}")
                if mutated_battery_change and battery_change == mutated_battery_change:
                    print(f"This invalid battery change underwent mutation")
                else:
                    print(f"This invalid battery change did not undergo mutation")
    return population

# %% [markdown]
# # Running GA

# %%
def extract_best_schedule(population, fitness_values):
    # Find the best schedule based on the minimum fitness value
    best_index = np.argmin(fitness_values)
    best_schedule = population[best_index]
    return best_schedule

# %%
def prepare_plot_data(best_schedule, df):
    timestamps = df.index
    hourly_consumption = df['Hourly consumption (kWh)']
    grid_usage = [entry[0] for entry in best_schedule]
    pv_usage = [entry[1] for entry in best_schedule]
    battery_soc = [entry[3] for entry in best_schedule]
    battery_change = [entry[2] for entry in best_schedule]
    
    # For graphing, multiply the battery_change by -1 so that in the graph, a positive value for the battery_change profile is 
    # the battery discharging (same as grid discharging) and negative shows the battery charging
    battery_change = [-1 * value for value in battery_change]
    return timestamps, grid_usage, pv_usage, battery_soc, battery_change, hourly_consumption

# %%
def plot_schedule_battery_change(timestamps, grid_usage, pv_usage, battery_change, hourly_consumption):
    plt.figure(figsize=(12, 6))
    plt.plot(timestamps, grid_usage, label='Grid Usage (kWh)', color='blue')
    plt.plot(timestamps, pv_usage, label='PV Usage (kWh)', color='orange')
    plt.plot(timestamps, battery_change, label='Battery Charge and Discharge Profile (kWh)', color='red')
    plt.plot(timestamps, hourly_consumption, label='Energy Consumption (kWh)', color='black')
    plt.xlabel('Time')
    plt.ylabel('Energy (kWh)')
    plt.title('Electricity Usage from Grid, Battery and PV System')
    plt.legend(loc='upper right')
    plt.ylim(-100, 600)  # Set y-axis limits
    plt.grid(True)
    plt.show()

# %%
def plot_schedule_battery_soc(timestamps, grid_usage, pv_usage, battery_soc, hourly_consumption):
    plt.figure(figsize=(12, 6))
    plt.plot(timestamps, grid_usage, label='Grid Usage (kWh)', color='blue')
    plt.plot(timestamps, pv_usage, label='PV Usage (kWh)', color='orange')
    plt.plot(timestamps, battery_soc, label='Battery State of Charge (kWh)', color='green')
    plt.plot(timestamps, hourly_consumption, label='Energy Consumption (kWh)', color='black')
    plt.xlabel('Time')
    plt.ylabel('Energy (kWh)')
    plt.title('Electricity Usage from Grid, Battery and PV system')
    plt.legend(loc='upper right')
    plt.ylim(0, 600)  # Set y-axis limits
    plt.grid(True)
    plt.show()

# %%
def save_best_schedule_to_csv(best_schedule, original_df, filename):
    # Create a pandas DataFrame from the best schedule
    df = pd.DataFrame(best_schedule, columns=['Grid Usage (kWh)', 'PV Used during this timestep (kWh)', 'Battery Charge/Discharge (kWh)', 'Battery State of Charge (kWh)', 'Hour', 'PV into Battery (kWh)', 'Battery Change not including PV (kWh)'])
    
    # Drop the 'Hour' column as it is not required in the CSV file
    df = df.drop(columns=['Hour'])
    df['Timestamp'] = original_df.index
    df.set_index('Timestamp', inplace=True)
    df['Hourly Consumption (kWh)'] = original_df['Hourly consumption (kWh)']
    df['TOU rate (€/kWh)'] = original_df['TOU (€/kWh)']
    df['Hourly Cost (€)'] = df['TOU rate (€/kWh)'] * df['Grid Usage (kWh)']
    df['Energy Balance'] = df['Hourly Consumption (kWh)'] + df['Battery Charge/Discharge (kWh)'] - df['Grid Usage (kWh)'] - df['PV Used during this timestep (kWh)']
    df['Energy Balance'] = df['Energy Balance'].round(4)
    
    # Save the DataFrame to a CSV file
    df.to_csv(filename)

# %%
def run(df, n_c, n_e, max_iterations):
    tou_rates = df['TOU (€/kWh)'].values
    P = init_population(df, pop_size)
    #print(f"Length of initial population = {len(P)}")
    initial_fitnesses, _ = evaluate_population(P, df)
    #print(f"Initial fitnesses = {initial_fitnesses[:20]}")
    
    for iteration in range(max_iterations):
        print(f"-----"* 20)
        print(f"Beginning of iteration {iteration}")
        population_fitnesses, _ = evaluate_population(P, df)
        best_solutions = select_top_n(P, df, int(len(P) * n_e))
        
        '''
        # Debugging 
        sched_counter = 0
        for solution in best_solutions:
            sched_counter += 1
            fitness_of_schedule = schedule_fitness(solution, df)
            print(f"Schedule number = {sched_counter}, fitness = {fitness_of_schedule}")
        
        print(f"Length of best solutions = {len(best_solutions)}")
        '''
        
        # Offspring includes the best_solutions (parents) and the additional offspring
        offspring = crossover(P, best_solutions, n_c, n_e)
        #print(f"Length of offspring = {len(offspring)}")
        #print(f"Length of best solutions after offspring = {len(best_solutions)}")
        print(f"Offspring created")
        
        #P_resolved = resolve_conflict(offspring, df)
        #print(f"Length of P_resolved = {len(P_resolved)}")

        # Fill up the next population with random solutions
        if len(offspring) < pop_size:
            offspring += init_population(df, pop_size-len(offspring))
        print(f"Random solutions added to offspring")
       

        # Create elite solutions
        #elite_solutions = select_top_n(P_resolved, df, num_elites)

        # Population without elites will be mutated
        offspring_less_best = ([sol for sol in offspring if sol not in best_solutions])
        
        print(f"Best Solutions removed from offspring")

        mutated_P = mutation(offspring_less_best)
        print(f"Offspring less best population mutated")

        P_resolved = resolve_conflict(mutated_P, df)
        print(f"Mutated population conflicts resolved")

        P = P_resolved + copy.deepcopy(best_solutions)
        print(f"Resolved conflict population combined with best solutions to form generation final population")
        
        
        # Evaluate fitness scores of next generation for tracking fitness scores
        next_gen_fitness_scores, _ = evaluate_population(P, df)
        print(f"Population fitnesses evaluated")
        
            
            
        best_fitness_score = min(next_gen_fitness_scores)
        print(f"Iteration {iteration}, Best fitness = {best_fitness_score}")
        
    best_overall_score = min(next_gen_fitness_scores)
    
    best_schedule = extract_best_schedule(P, next_gen_fitness_scores)
    save_best_schedule_to_csv(best_schedule, df, 'SPOT_TOU_NON_GREEDY_03_06_2022_to_08_06_2022_200kWh.csv')
    timestamps, grid_usage, pv_usage, battery_soc, battery_change, hourly_consumption = prepare_plot_data(best_schedule, df)
    plot_schedule_battery_change(timestamps, grid_usage, pv_usage, battery_change, hourly_consumption)
    plot_schedule_battery_soc(timestamps, grid_usage, pv_usage, battery_soc, hourly_consumption)
    
    for entry in best_schedule:
        tou_rate = df['TOU (€/kWh)'][entry[4]]
        pv_available = df['PV Energy Prediction (kWh)'][entry[4]]
        hourly_consumption = df['Hourly consumption (kWh)'][entry[4]]
        #print(f"Hour {entry[4]}: TOU rate = {tou_rate} Hourly Consumption = {hourly_consumption}, Grid Usage = {entry[0]:.2f} kWh, PV Used = {entry[1]:.2f} kWh, "
          #f"Battery Change = {entry[2]:.2f} kWh, SOC = {entry[3]:.2f} kWh")
        #print(f"PV available = {pv_available:.5f}, PV used now = {entry[1]:.5f}, PV into battery = {entry[5]:.5f}")
        #print(f"Entry = {entry[5]}")
        print(f"Hour = {entry[4]}, TOU rate = {tou_rate}, Hourly Consumption = {hourly_consumption}, Grid Usage (into battery + used now) = {entry[0]:.3f}, PV used = {entry[1]:.3f}, PV into battery = {entry[5]:.3f}, pv available = {pv_available}, battery change not pv = {entry[6]:.3f}, Total Battery change = {entry[2]:.3f}, SOC = {entry[3]:.3f}")

    
    print(f"Best score after {max_iterations} Iterations = {best_overall_score}")

# %%
run(df, n_c, n_e, max_iterations)
# Out:
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 0
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 0, Best fitness = 8065.151796012602
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 1
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 1, Best fitness = 8054.15491377182
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 2
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 2, Best fitness = 8032.101347171584
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 3
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 3, Best fitness = 8014.475170852956
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 4
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 4, Best fitness = 7975.178154941125
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 5
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 5, Best fitness = 7966.405959109782
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 6
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 6, Best fitness = 7960.062011394221
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 7
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 7, Best fitness = 7947.615832108966
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 8
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 8, Best fitness = 7947.615832108966
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 9
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 9, Best fitness = 7929.875819559442
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 10
# ERROR: BOTH PARENTS EQUAL, PICKING NEW PARENT (Attempt 1)
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 10, Best fitness = 7929.130977639162
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 11
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 11, Best fitness = 7926.34662723274
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 12
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 12, Best fitness = 7921.938487507184
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 13
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 13, Best fitness = 7921.938487507184
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 14
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 14, Best fitness = 7920.846954757879
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 15
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 15, Best fitness = 7919.6599481564635
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 16
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 16, Best fitness = 7914.638060862087
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 17
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 17, Best fitness = 7912.014958454856
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 18
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 18, Best fitness = 7910.621879891331
# ----------------------------------------------------------------------------------------------------
# Beginning of iteration 19
# Offspring created
# Random solutions added to offspring
# Best Solutions removed from offspring
# Offspring less best population mutated
# Mutated population conflicts resolved
# Resolved conflict population combined with best solutions to form generation final population
# Population fitnesses evaluated
# Iteration 19, Best fitness = 7908.60433956954
# Hour = 0, TOU rate = 0.23, Hourly Consumption = 98, Grid Usage (into battery + used now) = 150.960, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 52.960
# Hour = 1, TOU rate = 0.28, Hourly Consumption = 78, Grid Usage (into battery + used now) = 130.960, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 105.920
# Hour = 2, TOU rate = 0.27, Hourly Consumption = 81, Grid Usage (into battery + used now) = 130.825, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 49.824, Total Battery change = 49.825, SOC = 155.745
# Hour = 3, TOU rate = 0.25, Hourly Consumption = 87, Grid Usage (into battery + used now) = 110.438, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 23.437, Total Battery change = 23.438, SOC = 179.183
# Hour = 4, TOU rate = 0.22, Hourly Consumption = 52, Grid Usage (into battery + used now) = 68.212, PV used = 0.033, PV into battery = 0.367, pv available = 0.3996, battery change not pv = 15.878, Total Battery change = 16.245, SOC = 195.428
# Hour = 5, TOU rate = 0.2, Hourly Consumption = 91, Grid Usage (into battery + used now) = 93.595, PV used = 1.978, PV into battery = 4.572, pv available = 6.5502, battery change not pv = 0.000, Total Battery change = 4.572, SOC = 200.000
# Hour = 6, TOU rate = 0.3, Hourly Consumption = 177, Grid Usage (into battery + used now) = 161.470, PV used = 15.530, PV into battery = 0.000, pv available = 15.5304, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 7, TOU rate = 0.35, Hourly Consumption = 208, Grid Usage (into battery + used now) = 190.122, PV used = 17.878, PV into battery = 0.000, pv available = 17.87841818, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 8, TOU rate = 0.4, Hourly Consumption = 350, Grid Usage (into battery + used now) = 314.052, PV used = 35.948, PV into battery = 0.000, pv available = 35.9478, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 9, TOU rate = 0.45, Hourly Consumption = 261, Grid Usage (into battery + used now) = 207.413, PV used = 53.587, PV into battery = 0.000, pv available = 53.5869, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 10, TOU rate = 0.42, Hourly Consumption = 342, Grid Usage (into battery + used now) = 289.801, PV used = 52.199, PV into battery = 0.000, pv available = 52.1991, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 11, TOU rate = 0.38, Hourly Consumption = 366, Grid Usage (into battery + used now) = 304.234, PV used = 61.766, PV into battery = 0.000, pv available = 61.76603077, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 12, TOU rate = 0.46, Hourly Consumption = 269, Grid Usage (into battery + used now) = 204.224, PV used = 64.776, PV into battery = 0.000, pv available = 64.77635172, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 13, TOU rate = 0.44, Hourly Consumption = 169, Grid Usage (into battery + used now) = 97.084, PV used = 71.916, PV into battery = 0.000, pv available = 71.91621127, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 14, TOU rate = 0.52, Hourly Consumption = 253, Grid Usage (into battery + used now) = 192.557, PV used = 60.443, PV into battery = 0.000, pv available = 60.44290435, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 15, TOU rate = 0.53, Hourly Consumption = 310, Grid Usage (into battery + used now) = 257.333, PV used = 52.667, PV into battery = 0.000, pv available = 52.66679063, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 16, TOU rate = 0.47, Hourly Consumption = 409, Grid Usage (into battery + used now) = 367.338, PV used = 41.662, PV into battery = 0.000, pv available = 41.66208, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 17, TOU rate = 0.68, Hourly Consumption = 360, Grid Usage (into battery + used now) = 281.541, PV used = 25.499, PV into battery = 0.000, pv available = 25.49937515, battery change not pv = -52.960, Total Battery change = -52.960, SOC = 147.040
# Hour = 18, TOU rate = 0.64, Hourly Consumption = 301, Grid Usage (into battery + used now) = 217.779, PV used = 8.473, PV into battery = 2.986, pv available = 11.45946482, battery change not pv = -77.734, Total Battery change = -74.748, SOC = 72.292
# Hour = 19, TOU rate = 0.5, Hourly Consumption = 323, Grid Usage (into battery + used now) = 357.102, PV used = 0.141, PV into battery = 1.685, pv available = 1.8252, battery change not pv = 32.558, Total Battery change = 34.243, SOC = 106.535
# Hour = 20, TOU rate = 0.45, Hourly Consumption = 250, Grid Usage (into battery + used now) = 197.040, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = -52.960, Total Battery change = -52.960, SOC = 53.575
# Hour = 21, TOU rate = 0.35, Hourly Consumption = 238, Grid Usage (into battery + used now) = 290.960, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 106.536
# Hour = 22, TOU rate = 0.29, Hourly Consumption = 215, Grid Usage (into battery + used now) = 162.040, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = -52.960, Total Battery change = -52.960, SOC = 53.576
# Hour = 23, TOU rate = 0.22, Hourly Consumption = 176, Grid Usage (into battery + used now) = 228.960, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 106.536
# Hour = 24, TOU rate = 0.23, Hourly Consumption = 149, Grid Usage (into battery + used now) = 124.620, PV used = 0.001, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = -24.379, Total Battery change = -24.379, SOC = 82.157
# Hour = 25, TOU rate = 0.28, Hourly Consumption = 114, Grid Usage (into battery + used now) = 186.451, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 72.450, Total Battery change = 72.451, SOC = 154.608
# Hour = 26, TOU rate = 0.27, Hourly Consumption = 119, Grid Usage (into battery + used now) = 149.508, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 30.508, Total Battery change = 30.508, SOC = 185.116
# Hour = 27, TOU rate = 0.25, Hourly Consumption = 95, Grid Usage (into battery + used now) = 44.688, PV used = 0.001, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = -50.312, Total Battery change = -50.312, SOC = 134.804
# Hour = 28, TOU rate = 0.22, Hourly Consumption = 70, Grid Usage (into battery + used now) = 123.117, PV used = 0.023, PV into battery = 0.385, pv available = 0.408154891, battery change not pv = 52.756, Total Battery change = 53.141, SOC = 187.945
# Hour = 29, TOU rate = 0.2, Hourly Consumption = 161, Grid Usage (into battery + used now) = 167.664, PV used = 0.218, PV into battery = 1.057, pv available = 1.2744, battery change not pv = 5.825, Total Battery change = 6.881, SOC = 194.826
# Hour = 30, TOU rate = 0.3, Hourly Consumption = 249, Grid Usage (into battery + used now) = 246.443, PV used = 3.558, PV into battery = 1.001, pv available = 4.55895, battery change not pv = 0.000, Total Battery change = 1.001, SOC = 195.827
# Hour = 31, TOU rate = 0.35, Hourly Consumption = 302, Grid Usage (into battery + used now) = 274.102, PV used = 27.898, PV into battery = 0.000, pv available = 27.8982, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 195.827
# Hour = 32, TOU rate = 0.4, Hourly Consumption = 245, Grid Usage (into battery + used now) = 209.355, PV used = 35.645, PV into battery = 0.000, pv available = 35.6454, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 195.827
# Hour = 33, TOU rate = 0.45, Hourly Consumption = 319, Grid Usage (into battery + used now) = 265.753, PV used = 53.247, PV into battery = 0.000, pv available = 53.24724, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 195.827
# Hour = 34, TOU rate = 0.42, Hourly Consumption = 299, Grid Usage (into battery + used now) = 236.945, PV used = 62.055, PV into battery = 0.000, pv available = 62.05512414, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 195.827
# Hour = 35, TOU rate = 0.38, Hourly Consumption = 324, Grid Usage (into battery + used now) = 257.510, PV used = 66.490, PV into battery = 0.000, pv available = 66.49010847, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 195.827
# Hour = 36, TOU rate = 0.46, Hourly Consumption = 203, Grid Usage (into battery + used now) = 138.224, PV used = 64.776, PV into battery = 0.000, pv available = 64.77635172, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 195.827
# Hour = 37, TOU rate = 0.44, Hourly Consumption = 259, Grid Usage (into battery + used now) = 205.038, PV used = 53.962, PV into battery = 0.000, pv available = 53.96154545, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 195.827
# Hour = 38, TOU rate = 0.52, Hourly Consumption = 242, Grid Usage (into battery + used now) = 204.582, PV used = 37.418, PV into battery = 0.000, pv available = 37.41787636, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 195.827
# Hour = 39, TOU rate = 0.53, Hourly Consumption = 193, Grid Usage (into battery + used now) = 150.073, PV used = 42.927, PV into battery = 0.000, pv available = 42.92656364, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 195.827
# Hour = 40, TOU rate = 0.47, Hourly Consumption = 215, Grid Usage (into battery + used now) = 189.501, PV used = 25.499, PV into battery = 0.000, pv available = 25.49937515, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 195.827
# Hour = 41, TOU rate = 0.68, Hourly Consumption = 178, Grid Usage (into battery + used now) = 91.643, PV used = 16.568, PV into battery = 0.000, pv available = 16.5678722, battery change not pv = -69.789, Total Battery change = -69.789, SOC = 126.038
# Hour = 42, TOU rate = 0.64, Hourly Consumption = 144, Grid Usage (into battery + used now) = 87.705, PV used = 5.532, PV into battery = 2.196, pv available = 7.728482888, battery change not pv = -52.960, Total Battery change = -50.763, SOC = 75.275
# Hour = 43, TOU rate = 0.5, Hourly Consumption = 141, Grid Usage (into battery + used now) = 94.826, PV used = 1.851, PV into battery = 0.612, pv available = 2.4624, battery change not pv = -44.936, Total Battery change = -44.324, SOC = 30.951
# Hour = 44, TOU rate = 0.45, Hourly Consumption = 95, Grid Usage (into battery + used now) = 73.538, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = -21.462, Total Battery change = -21.462, SOC = 9.489
# Hour = 45, TOU rate = 0.35, Hourly Consumption = 121, Grid Usage (into battery + used now) = 173.960, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 62.449
# Hour = 46, TOU rate = 0.29, Hourly Consumption = 136, Grid Usage (into battery + used now) = 184.187, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 48.187, Total Battery change = 48.187, SOC = 110.636
# Hour = 47, TOU rate = 0.22, Hourly Consumption = 102, Grid Usage (into battery + used now) = 141.729, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 39.728, Total Battery change = 39.729, SOC = 150.365
# Hour = 48, TOU rate = 0.23, Hourly Consumption = 93, Grid Usage (into battery + used now) = 133.260, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = 40.259, Total Battery change = 40.260, SOC = 190.625
# Hour = 49, TOU rate = 0.28, Hourly Consumption = 88, Grid Usage (into battery + used now) = 92.965, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 4.965, Total Battery change = 4.965, SOC = 195.590
# Hour = 50, TOU rate = 0.27, Hourly Consumption = 79, Grid Usage (into battery + used now) = 81.336, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 2.335, Total Battery change = 2.336, SOC = 197.926
# Hour = 51, TOU rate = 0.25, Hourly Consumption = 79, Grid Usage (into battery + used now) = 80.099, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 1.098, Total Battery change = 1.099, SOC = 199.025
# Hour = 52, TOU rate = 0.22, Hourly Consumption = 67, Grid Usage (into battery + used now) = 67.656, PV used = 0.081, PV into battery = 0.469, pv available = 0.5508, battery change not pv = 0.268, Total Battery change = 0.737, SOC = 199.762
# Hour = 53, TOU rate = 0.2, Hourly Consumption = 49, Grid Usage (into battery + used now) = 45.801, PV used = 3.437, PV into battery = 0.238, pv available = 3.6747, battery change not pv = 0.000, Total Battery change = 0.238, SOC = 200.000
# Hour = 54, TOU rate = 0.3, Hourly Consumption = 98, Grid Usage (into battery + used now) = 84.106, PV used = 13.894, PV into battery = 0.000, pv available = 13.8942, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 55, TOU rate = 0.35, Hourly Consumption = 213, Grid Usage (into battery + used now) = 181.421, PV used = 31.579, PV into battery = 0.000, pv available = 31.5792, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 56, TOU rate = 0.4, Hourly Consumption = 210, Grid Usage (into battery + used now) = 156.038, PV used = 53.962, PV into battery = 0.000, pv available = 53.96154545, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 57, TOU rate = 0.45, Hourly Consumption = 145, Grid Usage (into battery + used now) = 98.835, PV used = 46.165, PV into battery = 0.000, pv available = 46.1646, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 58, TOU rate = 0.42, Hourly Consumption = 104, Grid Usage (into battery + used now) = 41.237, PV used = 62.763, PV into battery = 0.000, pv available = 62.76258, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 59, TOU rate = 0.38, Hourly Consumption = 132, Grid Usage (into battery + used now) = 60.084, PV used = 71.916, PV into battery = 0.000, pv available = 71.91621127, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 60, TOU rate = 0.46, Hourly Consumption = 80, Grid Usage (into battery + used now) = 8.084, PV used = 71.916, PV into battery = 0.000, pv available = 71.91621127, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 61, TOU rate = 0.44, Hourly Consumption = 121, Grid Usage (into battery + used now) = 49.084, PV used = 71.916, PV into battery = 0.000, pv available = 71.91621127, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 62, TOU rate = 0.52, Hourly Consumption = 165, Grid Usage (into battery + used now) = 100.224, PV used = 64.776, PV into battery = 0.000, pv available = 64.77635172, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 63, TOU rate = 0.53, Hourly Consumption = 203, Grid Usage (into battery + used now) = 150.333, PV used = 52.667, PV into battery = 0.000, pv available = 52.66679063, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 64, TOU rate = 0.47, Hourly Consumption = 185, Grid Usage (into battery + used now) = 147.506, PV used = 37.494, PV into battery = 0.000, pv available = 37.49365385, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 200.000
# Hour = 65, TOU rate = 0.68, Hourly Consumption = 170, Grid Usage (into battery + used now) = 91.541, PV used = 25.499, PV into battery = 0.000, pv available = 25.49937515, battery change not pv = -52.960, Total Battery change = -52.960, SOC = 147.040
# Hour = 66, TOU rate = 0.64, Hourly Consumption = 125, Grid Usage (into battery + used now) = 51.560, PV used = 9.412, PV into battery = 2.047, pv available = 11.45946482, battery change not pv = -66.074, Total Battery change = -64.027, SOC = 83.013
# Hour = 67, TOU rate = 0.5, Hourly Consumption = 101, Grid Usage (into battery + used now) = 48.607, PV used = 1.973, PV into battery = 0.489, pv available = 2.4624, battery change not pv = -50.909, Total Battery change = -50.420, SOC = 32.593
# Hour = 68, TOU rate = 0.45, Hourly Consumption = 95, Grid Usage (into battery + used now) = 70.793, PV used = 0.001, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = -24.207, Total Battery change = -24.207, SOC = 8.387
# Hour = 69, TOU rate = 0.35, Hourly Consumption = 91, Grid Usage (into battery + used now) = 143.960, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 61.347
# Hour = 70, TOU rate = 0.29, Hourly Consumption = 68, Grid Usage (into battery + used now) = 31.987, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = -36.012, Total Battery change = -36.012, SOC = 25.334
# Hour = 71, TOU rate = 0.22, Hourly Consumption = 48, Grid Usage (into battery + used now) = 100.960, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 78.294
# Hour = 72, TOU rate = 0.23, Hourly Consumption = 40, Grid Usage (into battery + used now) = 92.960, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 131.254
# Hour = 73, TOU rate = 0.28, Hourly Consumption = 39, Grid Usage (into battery + used now) = 68.462, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = 29.462, Total Battery change = 29.462, SOC = 160.717
# Hour = 74, TOU rate = 0.27, Hourly Consumption = 39, Grid Usage (into battery + used now) = 52.859, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 13.859, Total Battery change = 13.859, SOC = 174.576
# Hour = 75, TOU rate = 0.25, Hourly Consumption = 39, Grid Usage (into battery + used now) = 45.519, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 6.519, Total Battery change = 6.519, SOC = 181.095
# Hour = 76, TOU rate = 0.22, Hourly Consumption = 49, Grid Usage (into battery + used now) = 48.838, PV used = 0.285, PV into battery = 0.123, pv available = 0.408154891, battery change not pv = 0.000, Total Battery change = 0.123, SOC = 181.218
# Hour = 77, TOU rate = 0.2, Hourly Consumption = 103, Grid Usage (into battery + used now) = 102.501, PV used = 0.499, PV into battery = 0.000, pv available = 0.498825, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 78, TOU rate = 0.3, Hourly Consumption = 198, Grid Usage (into battery + used now) = 195.624, PV used = 2.376, PV into battery = 0.000, pv available = 2.376, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 79, TOU rate = 0.35, Hourly Consumption = 207, Grid Usage (into battery + used now) = 191.594, PV used = 15.406, PV into battery = 0.000, pv available = 15.4062, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 80, TOU rate = 0.4, Hourly Consumption = 226, Grid Usage (into battery + used now) = 221.066, PV used = 4.934, PV into battery = 0.000, pv available = 4.933737931, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 81, TOU rate = 0.45, Hourly Consumption = 260, Grid Usage (into battery + used now) = 252.537, PV used = 7.463, PV into battery = 0.000, pv available = 7.463368421, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 82, TOU rate = 0.42, Hourly Consumption = 227, Grid Usage (into battery + used now) = 211.190, PV used = 15.810, PV into battery = 0.000, pv available = 15.8095125, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 83, TOU rate = 0.38, Hourly Consumption = 212, Grid Usage (into battery + used now) = 184.061, PV used = 27.939, PV into battery = 0.000, pv available = 27.93862262, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 84, TOU rate = 0.46, Hourly Consumption = 156, Grid Usage (into battery + used now) = 103.333, PV used = 52.667, PV into battery = 0.000, pv available = 52.66679063, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 85, TOU rate = 0.44, Hourly Consumption = 104, Grid Usage (into battery + used now) = 66.582, PV used = 37.418, PV into battery = 0.000, pv available = 37.41787636, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 86, TOU rate = 0.52, Hourly Consumption = 100, Grid Usage (into battery + used now) = 62.582, PV used = 37.418, PV into battery = 0.000, pv available = 37.41787636, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 87, TOU rate = 0.53, Hourly Consumption = 190, Grid Usage (into battery + used now) = 152.582, PV used = 37.418, PV into battery = 0.000, pv available = 37.41787636, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 88, TOU rate = 0.47, Hourly Consumption = 250, Grid Usage (into battery + used now) = 222.061, PV used = 27.939, PV into battery = 0.000, pv available = 27.93862262, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.218
# Hour = 89, TOU rate = 0.68, Hourly Consumption = 262, Grid Usage (into battery + used now) = 183.541, PV used = 25.499, PV into battery = 0.000, pv available = 25.49937515, battery change not pv = -52.960, Total Battery change = -52.960, SOC = 128.258
# Hour = 90, TOU rate = 0.64, Hourly Consumption = 219, Grid Usage (into battery + used now) = 156.294, PV used = 10.603, PV into battery = 0.856, pv available = 11.45946482, battery change not pv = -52.960, Total Battery change = -52.103, SOC = 76.155
# Hour = 91, TOU rate = 0.5, Hourly Consumption = 219, Grid Usage (into battery + used now) = 165.659, PV used = 2.461, PV into battery = 0.001, pv available = 2.4624, battery change not pv = -50.881, Total Battery change = -50.880, SOC = 25.275
# Hour = 92, TOU rate = 0.45, Hourly Consumption = 271, Grid Usage (into battery + used now) = 247.064, PV used = 0.001, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = -23.935, Total Battery change = -23.935, SOC = 1.340
# Hour = 93, TOU rate = 0.35, Hourly Consumption = 216, Grid Usage (into battery + used now) = 268.960, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 54.300
# Hour = 94, TOU rate = 0.29, Hourly Consumption = 175, Grid Usage (into battery + used now) = 227.960, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 107.261
# Hour = 95, TOU rate = 0.22, Hourly Consumption = 135, Grid Usage (into battery + used now) = 187.960, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 160.221
# Hour = 96, TOU rate = 0.23, Hourly Consumption = 115, Grid Usage (into battery + used now) = 127.942, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 12.942, Total Battery change = 12.942, SOC = 173.163
# Hour = 97, TOU rate = 0.28, Hourly Consumption = 81, Grid Usage (into battery + used now) = 87.088, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = 6.087, Total Battery change = 6.088, SOC = 179.251
# Hour = 98, TOU rate = 0.27, Hourly Consumption = 71, Grid Usage (into battery + used now) = 73.864, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 2.863, Total Battery change = 2.864, SOC = 182.115
# Hour = 99, TOU rate = 0.25, Hourly Consumption = 65, Grid Usage (into battery + used now) = 30.576, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = -34.424, Total Battery change = -34.424, SOC = 147.691
# Hour = 100, TOU rate = 0.22, Hourly Consumption = 57, Grid Usage (into battery + used now) = 85.713, PV used = 0.067, PV into battery = 0.646, pv available = 0.7128, battery change not pv = 28.134, Total Battery change = 28.780, SOC = 176.471
# Hour = 101, TOU rate = 0.2, Hourly Consumption = 136, Grid Usage (into battery + used now) = 140.585, PV used = 0.870, PV into battery = 2.381, pv available = 3.2508, battery change not pv = 3.075, Total Battery change = 5.455, SOC = 181.927
# Hour = 102, TOU rate = 0.3, Hourly Consumption = 191, Grid Usage (into battery + used now) = 177.106, PV used = 13.894, PV into battery = 0.000, pv available = 13.8942, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.927
# Hour = 103, TOU rate = 0.35, Hourly Consumption = 199, Grid Usage (into battery + used now) = 164.661, PV used = 34.339, PV into battery = 0.000, pv available = 34.3386, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.927
# Hour = 104, TOU rate = 0.4, Hourly Consumption = 215, Grid Usage (into battery + used now) = 171.486, PV used = 43.514, PV into battery = 0.000, pv available = 43.51447059, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.927
# Hour = 105, TOU rate = 0.45, Hourly Consumption = 223, Grid Usage (into battery + used now) = 169.413, PV used = 53.587, PV into battery = 0.000, pv available = 53.5869, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.927
# Hour = 106, TOU rate = 0.42, Hourly Consumption = 312, Grid Usage (into battery + used now) = 260.127, PV used = 51.873, PV into battery = 0.000, pv available = 51.87285, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.927
# Hour = 107, TOU rate = 0.38, Hourly Consumption = 278, Grid Usage (into battery + used now) = 227.083, PV used = 50.917, PV into battery = 0.000, pv available = 50.91729677, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.927
# Hour = 108, TOU rate = 0.46, Hourly Consumption = 265, Grid Usage (into battery + used now) = 216.485, PV used = 48.515, PV into battery = 0.000, pv available = 48.51514286, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.927
# Hour = 109, TOU rate = 0.44, Hourly Consumption = 236, Grid Usage (into battery + used now) = 208.061, PV used = 27.939, PV into battery = 0.000, pv available = 27.93862262, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.927
# Hour = 110, TOU rate = 0.52, Hourly Consumption = 333, Grid Usage (into battery + used now) = 307.501, PV used = 25.499, PV into battery = 0.000, pv available = 25.49937515, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.927
# Hour = 111, TOU rate = 0.53, Hourly Consumption = 286, Grid Usage (into battery + used now) = 266.283, PV used = 19.717, PV into battery = 0.000, pv available = 19.71664615, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.927
# Hour = 112, TOU rate = 0.47, Hourly Consumption = 323, Grid Usage (into battery + used now) = 306.432, PV used = 16.568, PV into battery = 0.000, pv available = 16.5678722, battery change not pv = 0.000, Total Battery change = 0.000, SOC = 181.927
# Hour = 113, TOU rate = 0.68, Hourly Consumption = 338, Grid Usage (into battery + used now) = 273.581, PV used = 11.459, PV into battery = 0.000, pv available = 11.45946482, battery change not pv = -52.960, Total Battery change = -52.960, SOC = 128.967
# Hour = 114, TOU rate = 0.64, Hourly Consumption = 253, Grid Usage (into battery + used now) = 195.688, PV used = 4.588, PV into battery = 0.236, pv available = 4.82408933, battery change not pv = -52.960, Total Battery change = -52.724, SOC = 76.243
# Hour = 115, TOU rate = 0.5, Hourly Consumption = 297, Grid Usage (into battery + used now) = 245.376, PV used = 1.750, PV into battery = 0.076, pv available = 1.8252, battery change not pv = -49.950, Total Battery change = -49.874, SOC = 26.369
# Hour = 116, TOU rate = 0.45, Hourly Consumption = 250, Grid Usage (into battery + used now) = 277.219, PV used = 0.000, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = 27.219, Total Battery change = 27.219, SOC = 53.588
# Hour = 117, TOU rate = 0.35, Hourly Consumption = 234, Grid Usage (into battery + used now) = 181.040, PV used = 0.001, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = -52.960, Total Battery change = -52.960, SOC = 0.628
# Hour = 118, TOU rate = 0.29, Hourly Consumption = 200, Grid Usage (into battery + used now) = 252.960, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 52.960, Total Battery change = 52.960, SOC = 53.588
# Hour = 119, TOU rate = 0.22, Hourly Consumption = 170, Grid Usage (into battery + used now) = 117.040, PV used = 0.001, PV into battery = 0.000, pv available = 0.000606793, battery change not pv = -52.960, Total Battery change = -52.960, SOC = 0.629
# Hour = 120, TOU rate = 0.23, Hourly Consumption = 142, Grid Usage (into battery + used now) = 153.819, PV used = 0.000, PV into battery = 0.001, pv available = 0.000606793, battery change not pv = 11.818, Total Battery change = 11.819, SOC = 12.447
# Best score after 20 Iterations = 7908.60433956954
